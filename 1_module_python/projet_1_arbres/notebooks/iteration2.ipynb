# %% [markdown]
# # Itération 2
#
# #### Analyse de l’état de la diversité des arbres
#
# Objectifs de l’activité
#
# ● Analyser la répartition des espèces d’arbres à Grenoble, l’évolution de cette diversité au cours du temps, comparaison avec les objectifs de la Métro en termes de diversification des espèces.
#
# ● Utilisation d’autres structures de données : Sets, Dict

# %%
import csv
import zipfile
import os
import itertools
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

# %% [markdown]
# #### Consignes
#
# ### ● Pour commencer, identifiez tous les genres botaniques représentés à Grenoble. Combien y en a-t-il ? Essayez plusieurs manières de résoudre ce problème.

# %%
with open('../data/trees.csv') as file:

    reader = csv.DictReader(file)
    genre_list = []

    for row in reader:
        genre = row['GENRE_BOTA'].split()
        genre_list.append(genre)

# %%
list_genres = list(itertools.chain.from_iterable(genre_list))
list_genres
# Out:
# ['Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Ginkgo',
#  'Salix',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Catalpa',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Pyrus',
#  'Robinia',
#  'Robinia',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Zelkova',
#  'Parrotia',
#  'Fraxinus',
#  'Fagus',
#  'Fraxinus',
#  'Acer',
#  'Fraxinus',
#  'Magnolia',
#  'Taxus',
#  'Fagus',
#  'Fraxinus',
#  'Alnus',
#  'Alnus',
#  'Picea',
#  'Picea',
#  'Taxus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Acer',
#  'Magnolia',
#  'Fraxinus',
#  'Cupressus',
#  'Sequoiadendron',
#  'Fraxinus',
#  'Fagus',
#  'Pyrus',
#  'Pinus',
#  'Taxus',
#  'Betula',
#  'Fraxinus',
#  'Tilia',
#  'Acer',
#  'Tilia',
#  'Acer',
#  'Cedrus',
#  'Liriodendron',
#  'Acer',
#  'Pinus',
#  'Populus',
#  'Celtis',
#  'Cedrus',
#  'Acer',
#  'Tilia',
#  'Tilia',
#  'Picea',
#  'Celtis',
#  'Picea',
#  'Celtis',
#  'Populus',
#  'Celtis',
#  'Acer',
#  'Thuja',
#  'Sorbus',
#  'Picea',
#  'Populus',
#  'Acer',
#  'Sophora',
#  'Pinus',
#  'Robinia',
#  'Ginkgo',
#  'Fagus',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Ginkgo',
#  'Robinia',
#  'Sorbus',
#  'Acer',
#  'Acer',
#  'Populus',
#  'Liquidambar',
#  'Acer',
#  'Tilia',
#  'Celtis',
#  'Celtis',
#  'Acer',
#  'Pinus',
#  'Pinus',
#  'Tilia',
#  'Thuja',
#  'Prunus',
#  'Picea',
#  'Tilia',
#  'Ginkgo',
#  'Fraxinus',
#  'Thuja',
#  'Cedrus',
#  'Acer',
#  'Robinia',
#  'Populus',
#  'Acer',
#  'Populus',
#  'Picea',
#  'Acer',
#  'Acer',
#  'Prunus',
#  'Acer',
#  'Celtis',
#  'Acer',
#  'Populus',
#  'Tilia',
#  'Celtis',
#  'Acer',
#  'Liquidambar',
#  'Robinia',
#  'Platanus',
#  'Pinus',
#  'Cedrus',
#  'Cedrus',
#  'Acer',
#  'Celtis',
#  'Acer',
#  'Celtis',
#  'Populus',
#  'Populus',
#  'Cedrus',
#  'Pinus',
#  'Calocedrus',
#  'Sophora',
#  'Pinus',
#  'Tilia',
#  'Prunus',
#  'Zelkova',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Celtis',
#  'Cedrus',
#  'Sophora',
#  'Paulownia',
#  'Fraxinus',
#  'Calocedrus',
#  'Cedrus',
#  'Populus',
#  'Fraxinus',
#  'Zelkova',
#  'Celtis',
#  'Pinus',
#  'Zelkova',
#  'Picea',
#  'Celtis',
#  'Ginkgo',
#  'Robinia',
#  'Pinus',
#  'Ginkgo',
#  'Tilia',
#  'Celtis',
#  'Acer',
#  'Picea',
#  'Acer',
#  'Acer',
#  'Thuja',
#  'Celtis',
#  'Celtis',
#  'Sorbus',
#  'Cedrus',
#  'Picea',
#  'Liquidambar',
#  'Sophora',
#  'Robinia',
#  'Sophora',
#  'Gymnocladus',
#  'Ulmus',
#  'Tilia',
#  'Celtis',
#  'Celtis',
#  'Sophora',
#  'Pinus',
#  'Prunus',
#  'Picea',
#  'Sophora',
#  'Corylus',
#  'Cedrus',
#  'Acer',
#  'Tilia',
#  'Celtis',
#  'Acer',
#  'Celtis',
#  'Acer',
#  'Picea',
#  'Pinus',
#  'Pinus',
#  'Sorbus',
#  'Platanus',
#  'Sophora',
#  'Fraxinus',
#  'Zelkova',
#  'Pinus',
#  'Thuja',
#  'Cedrus',
#  'Tilia',
#  'Tilia',
#  'Prunus',
#  'Acer',
#  'Acer',
#  'Robinia',
#  'Liquidambar',
#  'Tilia',
#  'Sophora',
#  'Platanus',
#  'Acer',
#  'Picea',
#  'Acer',
#  'Celtis',
#  'Morus',
#  'Pinus',
#  'Ginkgo',
#  'Platanus',
#  'Sorbus',
#  'Sophora',
#  'Ginkgo',
#  'Populus',
#  'Acer',
#  'Celtis',
#  'Cedrus',
#  'Corylus',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Liriodendron',
#  'Betula',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Pinus',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Acer',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Acer',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Acer',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Clerodendron',
#  'Taxus',
#  'Gleditsia',
#  'Taxus',
#  'Libocedrus',
#  'Quercus',
#  'Fraxinus',
#  'Lagerstroemia',
#  'Celtis',
#  'Acer',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Magnolia',
#  'Fraxinus',
#  'Taxus',
#  'Alnus',
#  'Alnus',
#  'Acer',
#  'Taxodium',
#  'Alnus',
#  'Fraxinus',
#  'Taxus',
#  'Amélanchier',
#  'Amélanchier',
#  'Amélanchier',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Quercus',
#  'Cupressus',
#  'Cercidiphyllum',
#  'Fraxinus',
#  'Acer',
#  'Taxus',
#  'Pyrus',
#  'Robinia',
#  'Acer',
#  'Cedrus',
#  'Alnus',
#  'Fraxinus',
#  'Taxus',
#  'Liriodendron',
#  'Taxus',
#  'Magnolia',
#  'Cedrus',
#  'Pyrus',
#  'Alnus',
#  'Ilex',
#  'Magnolia',
#  'Pinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Magnolia',
#  'Alnus',
#  'Picea',
#  'Tilia',
#  'Acer',
#  'Robinia',
#  'Taxus',
#  'Alnus',
#  'Picea',
#  'Taxus',
#  'Alnus',
#  'Tilia',
#  'Fraxinus',
#  'Taxus',
#  'Alnus',
#  'Magnolia',
#  'Malus',
#  'Malus',
#  'Malus',
#  'Fraxinus',
#  'Cedrela',
#  'Cedrela',
#  'Prunus',
#  'Photinia',
#  'Malus',
#  'Paulownia',
#  'Cedrela',
#  'Sorbus',
#  'Prunus',
#  'Prunus',
#  'Prunus',
#  'Paulownia',
#  'Sorbus',
#  'Paulownia',
#  'Prunus',
#  'Malus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Platanus',
#  'Liriodendron',
#  'Liriodendron',
#  'Betula',
#  'Robinia',
#  'Pinus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Celtis',
#  'Celtis',
#  'Celtis',
#  'Celtis',
#  'Celtis',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Pinus',
#  'Robinia',
#  'Paulownia',
#  'Pinus',
#  'Robinia',
#  'Pinus',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Tetradium',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Tilia',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Pinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Pinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Pinus',
#  'Fraxinus',
#  'Ulmus',
#  'Ulmus',
#  'Acer',
#  'Acer',
#  'Populus',
#  'Acer',
#  'Populus',
#  'Acer',
#  'Acer',
#  'Ulmus',
#  'Ulmus',
#  'Liriodendron',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Pinus',
#  'Cupressus',
#  'Pinus',
#  'Pinus',
#  'Acer',
#  'Pinus',
#  'Pinus',
#  'Acer',
#  'Acer',
#  'Thuja',
#  'Acer',
#  'Koelreuteria',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Pinus',
#  'Acer',
#  'Betula',
#  'Malus',
#  'Halesia',
#  'Crataegus',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Cedrus',
#  'Crataegus',
#  'Morus',
#  'Morus',
#  'Morus',
#  'Aesculus',
#  'Aesculus',
#  'Prunus',
#  'Prunus',
#  'Prunus',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liriodendron',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Liquidambar',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Ptelea',
#  'Ptelea',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Betula',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Platanus',
#  'Prunus',
#  'Platanus',
#  'Prunus',
#  'Quercus',
#  'Fraxinus',
#  'Acer',
#  'Celtis',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Acer',
#  'Chimonanthus',
#  'Thuja',
#  'Chimonanthus',
#  'Chimonanthus',
#  'Pyrus',
#  'Pyrus',
#  'Pyrus',
#  'Populus',
#  'Populus',
#  'Pinus',
#  'Betula',
#  'Populus',
#  'Populus',
#  'Picea',
#  'Populus',
#  'Robinia',
#  'Acer',
#  'Populus',
#  'Tilia',
#  'Pinus',
#  'Populus',
#  'Populus',
#  'Populus',
#  'Betula',
#  'Populus',
#  'Betula',
#  'Ulmus',
#  'Salix',
#  'Populus',
#  'Pinus',
#  'Populus',
#  'Tilia',
#  'Alnus',
#  'Acer',
#  'Fraxinus',
#  'Ulmus',
#  'Fraxinus',
#  'Fraxinus',
#  'Acer',
#  'Acer',
#  'Alnus',
#  'Alnus',
#  'Alnus',
#  'Fraxinus',
#  'Fraxinus',
#  'Ulmus',
#  'Acer',
#  'Fraxinus',
#  'Alnus',
#  'Amélanchier',
#  'Alnus',
#  'Acer',
#  'Carpinus',
#  'Carpinus',
#  'Betula',
#  'Koelreuteria',
#  'Acer',
#  'Koelreuteria',
#  'Koelreuteria',
#  'Acer',
#  'Koelreuteria',
#  'Acer',
#  'Betula',
#  'Koelreuteria',
#  'Acer',
#  'Koelreuteria',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Betula',
#  'Betula',
#  'Koelreuteria',
#  'Betula',
#  'Acer',
#  'Betula',
#  'Koelreuteria',
#  'Koelreuteria',
#  'Alnus',
#  'Metasequoia',
#  'Tilia',
#  'Prunus',
#  'Pinus',
#  'Acer',
#  'Prunus',
#  'Malus',
#  'Malus',
#  'Cercis',
#  'Cercis',
#  'Acer',
#  'Pyrus',
#  'Malus',
#  'Pyrus',
#  'Malus',
#  'Prunus',
#  'Prunus',
#  'Prunus',
#  'Malus',
#  'Malus',
#  'Acer',
#  ...]

# %%
Counter(list_genres)
# Out:
# Counter({'Acer': 5276,
#          'Platanus': 4663,
#          'Pinus': 2118,
#          'Tilia': 1770,
#          'Fraxinus': 1506,
#          'Carpinus': 1296,
#          'Betula': 1247,
#          'Prunus': 996,
#          'Populus': 966,
#          'Alnus': 826,
#          'Liquidambar': 809,
#          'Quercus': 677,
#          'Liriodendron': 507,
#          'Pyrus': 501,
#          'Aesculus': 459,
#          'Sophora': 426,
#          'Magnolia': 409,
#          'Cedrus': 407,
#          'Chamaecyparis': 373,
#          'Gleditsia': 352,
#          'Cercis': 351,
#          'Robinia': 287,
#          'Koelreuteria': 271,
#          'Fagus': 267,
#          'Malus': 262,
#          'Picea': 252,
#          'Zelkova': 233,
#          'Ulmus': 210,
#          'Cupressus': 203,
#          'Taxus': 202,
#          'Celtis': 193,
#          'Corylus': 174,
#          'Salix': 143,
#          'Ginkgo': 111,
#          'Crataegus': 108,
#          'Paulownia': 101,
#          'Morus': 100,
#          'Cupressocyparis': 100,
#          'Amélanchier': 96,
#          'Catalpa': 89,
#          'Sorbus': 88,
#          'Tetradium': 88,
#          'Metasequoia': 81,
#          'Ailanthus': 80,
#          'Albizia': 67,
#          'Juglans': 66,
#          'Parrotia': 54,
#          'Pterocarya': 52,
#          'Lagerstroemia': 50,
#          'Thuja': 48,
#          'Libocedrus': 47,
#          'Cedrela': 46,
#          'Cladastris': 45,
#          'Ostrya': 44,
#          'Syringa': 41,
#          'Chionanthus': 33,
#          'Sambucus': 33,
#          'Abies': 28,
#          'Ilex': 24,
#          'Cornus': 23,
#          'Broussonetia': 23,
#          'Trachycarpus': 22,
#          'Ficus': 19,
#          'Eleagnus': 19,
#          'Buxus': 17,
#          'Diospyros': 17,
#          'Sequoiadendron': 14,
#          'Phellodendron': 13,
#          'Laburnum': 13,
#          'Pteroceltis': 12,
#          'Cydonia': 11,
#          'Cotinus': 11,
#          'Photinia': 10,
#          'Gymnocladus': 9,
#          'Taxodium': 9,
#          'Halesia': 9,
#          'Cercidiphyllum': 7,
#          'Davidia': 7,
#          'Mespilus': 7,
#          'Pistacia': 7,
#          'Rhus': 7,
#          'Lonicera': 6,
#          'Pterostyrax': 6,
#          'Clerodendron': 5,
#          'Olea': 5,
#          'Maclura': 5,
#          'Ligustrum': 5,
#          'Larix': 5,
#          'Calocedrus': 4,
#          'Fontanesia': 4,
#          'Juniperus': 4,
#          'Chitalpa': 4,
#          'Ptelea': 3,
#          'Chimonanthus': 3,
#          'Phillyrea': 3,
#          'Eriobotrya': 3,
#          'Cephalotaxus': 3,
#          'Styrax': 3,
#          'Punica': 3,
#          'Araucaria': 2,
#          'Cryptomeria': 2,
#          'Hovenia': 2,
#          'Sterculia': 1,
#          'Rhamnus': 1,
#          'Castanea': 1,
#          'Eucalyptus': 1,
#          'Staphylea': 1,
#          'Sequoia': 1,
#          'Nyssa': 1,
#          'Sciadopitys': 1,
#          'Sorbopyrus': 1,
#          'Poncinos': 1})

# %%
counter_genres = Counter(list_genres)
len(counter_genres)
# Out:
# 112

# %% [markdown]
# Il existe 112 genres botaniques différents à Grenoble

# %% [markdown]
# ### ● Identifiez maintenant toutes les espèces différentes présentes à Grenoble. N’oubliez pas que les espèces sont une sous catégorie de genre botanique! (l’espèce est ‘Platanus Acerifolia’ et pas uniquement ‘Acerifolia’)

# %%
espèces_différentes = []

with open('../data/trees.csv', newline="") as file:

    reader = csv.DictReader(file, delimiter=",")
    next(reader)

    for row in reader:
        genre = row['GENRE_BOTA']
        espece = row['ESPECE']
        genre_espece = genre + ' ' + espece
        genre_espece = genre_espece.strip()
        espèces_différentes.append(genre_espece)

espèces_différentes
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Ginkgo biloba',
#  'Salix',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Catalpa bignonoides',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Pyrus',
#  'Robinia pseudoacacia',
#  'Robinia pseudoacacia',
#  '',
#  'Acer grosseri',
#  'Acer grosseri',
#  'Acer grosseri',
#  'Zelkova serrata',
#  'Parrotia persica',
#  'Fraxinus excelsior',
#  'Fagus sylvatica',
#  'Fraxinus excelsior',
#  'Acer negundo',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Taxus baccata',
#  'Fagus sylvatica',
#  'Fraxinus excelsior',
#  'Alnus cordata',
#  'Alnus cordata',
#  'Picea abies',
#  'Picea abies',
#  'Taxus baccata',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Acer negundo',
#  'Magnolia grandiflora',
#  'Fraxinus excelsior',
#  'Cupressus arizonica',
#  'Sequoiadendron giganteum',
#  'Fraxinus excelsior',
#  'Fagus sylvatica',
#  'Pyrus calleryana',
#  'Pinus nigra',
#  'Taxus baccata',
#  'Betula verrucosa',
#  'Fraxinus excelsior',
#  'Tilia platyphyllos',
#  'Acer pseudoplatanus',
#  'Tilia tomentosa',
#  'Acer platanoides',
#  'Cedrus deodara',
#  'Liriodendron tulipifera',
#  'Acer pseudoplatanus',
#  'Pinus sylvestris',
#  'Populus alba',
#  'Celtis australis',
#  'Cedrus deodara',
#  'Acer platanoides',
#  'Tilia cordata',
#  'Tilia cordata',
#  'Picea abies',
#  'Celtis australis',
#  'Picea abies',
#  'Celtis australis',
#  'Populus nigra',
#  'Celtis australis',
#  'Acer platanoides',
#  'Thuja',
#  'Sorbus aria',
#  'Picea abies',
#  'Populus alba',
#  'Acer negundo',
#  'Sophora japonica',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Ginkgo biloba',
#  'Fagus sylvatica',
#  'Acer cappadocicum',
#  'Acer pseudoplatanus',
#  'Acer campestre',
#  'Ginkgo biloba',
#  'Robinia pseudoacacia',
#  'Sorbus aria',
#  'Acer saccharinum',
#  'Acer saccharinum',
#  'Populus nigra',
#  'Liquidambar styraciflua',
#  'Acer pseudoplatanus',
#  'Tilia cordata',
#  'Celtis australis',
#  'Celtis australis',
#  'Acer campestre',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Tilia cordata',
#  'Thuja',
#  'Prunus spinosa',
#  'Picea abies',
#  'Tilia cordata',
#  'Ginkgo biloba',
#  'Fraxinus excelsior',
#  'Thuja',
#  'Cedrus atlantica',
#  'Acer pseudoplatanus',
#  'Robinia pseudoacacia',
#  'Populus nigra',
#  'Acer platanoides',
#  'Populus nigra',
#  'Picea abies',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Prunus spinosa',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer platanoides',
#  'Populus alba',
#  'Tilia cordata',
#  'Celtis australis',
#  'Acer cappadocicum',
#  'Liquidambar styraciflua',
#  'Robinia pseudoacacia',
#  'Platanus acerifolia',
#  'Pinus sylvestris',
#  'Cedrus atlantica',
#  'Cedrus atlantica',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer platanoides',
#  'Celtis australis',
#  'Populus nigra',
#  'Populus nigra',
#  'Cedrus atlantica',
#  'Pinus nigra',
#  'Calocedrus decurrens',
#  'Sophora japonica',
#  'Pinus wallichiana',
#  'Tilia cordata',
#  'Prunus cerasus',
#  'Zelkova serrata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Celtis australis',
#  'Cedrus atlantica',
#  'Sophora japonica',
#  'Paulownia tomentosa',
#  'Fraxinus excelsior',
#  'Calocedrus decurrens',
#  'Cedrus atlantica',
#  'Populus nigra',
#  'Fraxinus excelsior',
#  'Zelkova serrata',
#  'Celtis australis',
#  'Pinus nigra',
#  'Zelkova serrata',
#  'Picea abies',
#  'Celtis australis',
#  'Ginkgo biloba',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Ginkgo biloba',
#  'Tilia',
#  'Celtis australis',
#  'Acer campestre',
#  'Picea abies',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Thuja',
#  'Celtis australis',
#  'Celtis australis',
#  'Sorbus aucuparia',
#  'Cedrus atlantica',
#  'Picea abies',
#  'Liquidambar styraciflua',
#  'Sophora japonica',
#  'Robinia pseudoacacia',
#  'Sophora japonica',
#  'Gymnocladus dioicus',
#  'Ulmus minor',
#  'Tilia cordata',
#  'Celtis australis',
#  'Celtis australis',
#  'Sophora japonica',
#  'Pinus sylvestris',
#  'Prunus spinosa',
#  'Picea abies',
#  'Sophora japonica',
#  'Corylus colurna',
#  'Cedrus atlantica',
#  'Acer platanoides',
#  'Tilia cordata',
#  'Celtis australis',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer campestre',
#  'Picea abies',
#  'Pinus nigra',
#  'Pinus sylvestris',
#  'Sorbus aucuparia',
#  'Platanus acerifolia',
#  'Sophora japonica',
#  'Fraxinus excelsior',
#  'Zelkova serrata',
#  'Pinus nigra',
#  'Thuja',
#  'Cedrus atlantica',
#  'Tilia tomentosa',
#  'Tilia cordata',
#  'Prunus domestica',
#  'Acer campestre',
#  'Acer saccharinum',
#  'Robinia pseudoacacia',
#  'Liquidambar styraciflua',
#  'Tilia cordata',
#  'Sophora japonica',
#  'Platanus acerifolia',
#  'Acer pseudoplatanus',
#  'Picea abies',
#  'Acer platanoides',
#  'Celtis australis',
#  'Morus alba',
#  'Pinus sylvestris',
#  'Ginkgo biloba',
#  'Platanus acerifolia',
#  'Sorbus aria',
#  'Sophora japonica',
#  'Ginkgo biloba',
#  'Populus alba',
#  'Acer platanoides',
#  'Celtis australis',
#  'Cedrus atlantica',
#  'Corylus colurna',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer',
#  'Tilia tomentosa',
#  '',
#  '',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer saccharinum',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer saccharinum',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Clerodendron tricotonum',
#  'Taxus baccata',
#  'Gleditsia triacanthos',
#  'Taxus baccata',
#  'Libocedrus decurrens',
#  'Quercus robur',
#  'Fraxinus excelsior',
#  'Lagerstroemia indica',
#  'Celtis australis',
#  'Acer negundo',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Alnus cordata',
#  'Acer platanoides',
#  'Taxodium distychum',
#  'Alnus cordata',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Amélanchier canadensis',
#  'Amélanchier canadensis',
#  'Amélanchier canadensis',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Quercus macrocarpa',
#  'Cupressus arizonica',
#  'Cercidiphyllum japonicum',
#  'Fraxinus excelsior',
#  'Acer saccharinum',
#  'Taxus baccata',
#  'Pyrus calleryana',
#  'Robinia pseudoacacia',
#  'Acer platanoides',
#  'Cedrus atlantica',
#  'Alnus cordata',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Liriodendron tulipifera',
#  'Taxus baccata',
#  'Magnolia grandiflora',
#  'Cedrus atlantica',
#  'Pyrus calleryana',
#  'Alnus cordata',
#  'Ilex aquifolium',
#  'Magnolia grandiflora',
#  'Pinus nigra',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Alnus cordata',
#  'Picea abies',
#  'Tilia platyphyllos',
#  'Acer',
#  'Robinia pseudoacacia',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Picea abies',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Tilia platyphyllos',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Magnolia grandiflora',
#  'Malus floribunda',
#  'Malus floribunda',
#  'Malus floribunda',
#  'Fraxinus ornus',
#  'Cedrela sinensis',
#  'Cedrela sinensis',
#  'Prunus avium',
#  'Photinia villosa',
#  'Malus floribunda',
#  'Paulownia fortunei',
#  'Cedrela sinensis',
#  'Sorbus torminalis',
#  'Prunus padus',
#  'Prunus padus',
#  'Prunus padus',
#  'Paulownia fortunei',
#  'Sorbus torminalis',
#  'Paulownia fortunei',
#  'Prunus padus',
#  'Malus floribunda',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Platanus acerifolia',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Paulownia tomentosa',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Ulmus minor',
#  'Ulmus minor',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Populus nigra',
#  'Acer platanoides',
#  'Populus nigra',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Ulmus minor',
#  'Ulmus minor',
#  'Liriodendron tulipifera',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus platanor',
#  'Platanus platanor',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Pinus nigra',
#  'Cupressus arizonica',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Thuja occidentalis',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Betula verrucosa',
#  'Malus floribunda',
#  'Halesia carolina',
#  'Crataegus oxyacantha',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Cedrus deodara',
#  'Crataegus oxyacantha',
#  'Morus nigra',
#  'Morus nigra',
#  'Morus nigra',
#  'Aesculus hippocastanum',
#  'Aesculus hippocastanum',
#  'Prunus serrulata',
#  'Prunus serrulata',
#  'Prunus serrulata',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Ptelea trifoliata',
#  'Ptelea trifoliata',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  '',
#  '',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Betula verrucosa',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Quercus robur',
#  'Fraxinus angustifolia',
#  'Acer negundo',
#  'Celtis australis',
#  'Fraxinus americana',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Acer pseudoplatanus',
#  '',
#  '',
#  'Chimonanthus praecox',
#  'Thuja occidentalis',
#  'Chimonanthus praecox',
#  'Chimonanthus praecox',
#  'Pyrus calleryana',
#  'Pyrus calleryana',
#  'Pyrus calleryana',
#  'Populus nigra',
#  'Populus nigra',
#  'Pinus nigra',
#  'Betula verrucosa',
#  'Populus nigra',
#  'Populus nigra',
#  'Picea abies',
#  'Populus nigra',
#  'Robinia pseudoacacia',
#  'Acer',
#  'Populus nigra',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Betula verrucosa',
#  'Populus nigra',
#  'Betula verrucosa',
#  'Ulmus minor',
#  'Salix',
#  'Populus nigra',
#  'Pinus nigra',
#  'Populus nigra',
#  'Tilia mongolica',
#  'Alnus spaethii',
#  'Acer pseudoplatanus',
#  'Fraxinus americana',
#  'Ulmus resista',
#  'Fraxinus americana',
#  'Fraxinus americana',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Alnus cordata',
#  'Alnus spaethii',
#  'Alnus cordata',
#  'Fraxinus americana',
#  'Fraxinus americana',
#  'Ulmus resista',
#  'Acer pseudoplatanus',
#  'Fraxinus americana',
#  'Alnus incana',
#  'Amélanchier ovalis',
#  'Alnus glutinosa',
#  'Acer platanoides',
#  'Carpinus betulus',
#  'Carpinus betulus',
#  'Betula alba',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  ...]

# %%
for j in espèces_différentes:
    espèces_différentes.remove('')

espèces_différentes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 for j in espèces_différentes:
# ----> 2     espèces_différentes.remove('')
#       4 espèces_différentes
#
# ValueError: list.remove(x): x not in list

# %%
espèces_différentes
# Out:
# ['Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Ginkgo biloba',
#  'Salix',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Catalpa bignonoides',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Pyrus',
#  'Robinia pseudoacacia',
#  'Robinia pseudoacacia',
#  'Acer grosseri',
#  'Acer grosseri',
#  'Acer grosseri',
#  'Zelkova serrata',
#  'Parrotia persica',
#  'Fraxinus excelsior',
#  'Fagus sylvatica',
#  'Fraxinus excelsior',
#  'Acer negundo',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Taxus baccata',
#  'Fagus sylvatica',
#  'Fraxinus excelsior',
#  'Alnus cordata',
#  'Alnus cordata',
#  'Picea abies',
#  'Picea abies',
#  'Taxus baccata',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Acer negundo',
#  'Magnolia grandiflora',
#  'Fraxinus excelsior',
#  'Cupressus arizonica',
#  'Sequoiadendron giganteum',
#  'Fraxinus excelsior',
#  'Fagus sylvatica',
#  'Pyrus calleryana',
#  'Pinus nigra',
#  'Taxus baccata',
#  'Betula verrucosa',
#  'Fraxinus excelsior',
#  'Tilia platyphyllos',
#  'Acer pseudoplatanus',
#  'Tilia tomentosa',
#  'Acer platanoides',
#  'Cedrus deodara',
#  'Liriodendron tulipifera',
#  'Acer pseudoplatanus',
#  'Pinus sylvestris',
#  'Populus alba',
#  'Celtis australis',
#  'Cedrus deodara',
#  'Acer platanoides',
#  'Tilia cordata',
#  'Tilia cordata',
#  'Picea abies',
#  'Celtis australis',
#  'Picea abies',
#  'Celtis australis',
#  'Populus nigra',
#  'Celtis australis',
#  'Acer platanoides',
#  'Thuja',
#  'Sorbus aria',
#  'Picea abies',
#  'Populus alba',
#  'Acer negundo',
#  'Sophora japonica',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Ginkgo biloba',
#  'Fagus sylvatica',
#  'Acer cappadocicum',
#  'Acer pseudoplatanus',
#  'Acer campestre',
#  'Ginkgo biloba',
#  'Robinia pseudoacacia',
#  'Sorbus aria',
#  'Acer saccharinum',
#  'Acer saccharinum',
#  'Populus nigra',
#  'Liquidambar styraciflua',
#  'Acer pseudoplatanus',
#  'Tilia cordata',
#  'Celtis australis',
#  'Celtis australis',
#  'Acer campestre',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Tilia cordata',
#  'Thuja',
#  'Prunus spinosa',
#  'Picea abies',
#  'Tilia cordata',
#  'Ginkgo biloba',
#  'Fraxinus excelsior',
#  'Thuja',
#  'Cedrus atlantica',
#  'Acer pseudoplatanus',
#  'Robinia pseudoacacia',
#  'Populus nigra',
#  'Acer platanoides',
#  'Populus nigra',
#  'Picea abies',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Prunus spinosa',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer platanoides',
#  'Populus alba',
#  'Tilia cordata',
#  'Celtis australis',
#  'Acer cappadocicum',
#  'Liquidambar styraciflua',
#  'Robinia pseudoacacia',
#  'Platanus acerifolia',
#  'Pinus sylvestris',
#  'Cedrus atlantica',
#  'Cedrus atlantica',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer platanoides',
#  'Celtis australis',
#  'Populus nigra',
#  'Populus nigra',
#  'Cedrus atlantica',
#  'Pinus nigra',
#  'Calocedrus decurrens',
#  'Sophora japonica',
#  'Pinus wallichiana',
#  'Tilia cordata',
#  'Prunus cerasus',
#  'Zelkova serrata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Celtis australis',
#  'Cedrus atlantica',
#  'Sophora japonica',
#  'Paulownia tomentosa',
#  'Fraxinus excelsior',
#  'Calocedrus decurrens',
#  'Cedrus atlantica',
#  'Populus nigra',
#  'Fraxinus excelsior',
#  'Zelkova serrata',
#  'Celtis australis',
#  'Pinus nigra',
#  'Zelkova serrata',
#  'Picea abies',
#  'Celtis australis',
#  'Ginkgo biloba',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Ginkgo biloba',
#  'Tilia',
#  'Celtis australis',
#  'Acer campestre',
#  'Picea abies',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Thuja',
#  'Celtis australis',
#  'Celtis australis',
#  'Sorbus aucuparia',
#  'Cedrus atlantica',
#  'Picea abies',
#  'Liquidambar styraciflua',
#  'Sophora japonica',
#  'Robinia pseudoacacia',
#  'Sophora japonica',
#  'Gymnocladus dioicus',
#  'Ulmus minor',
#  'Tilia cordata',
#  'Celtis australis',
#  'Celtis australis',
#  'Sophora japonica',
#  'Pinus sylvestris',
#  'Prunus spinosa',
#  'Picea abies',
#  'Sophora japonica',
#  'Corylus colurna',
#  'Cedrus atlantica',
#  'Acer platanoides',
#  'Tilia cordata',
#  'Celtis australis',
#  'Acer platanoides',
#  'Celtis australis',
#  'Acer campestre',
#  'Picea abies',
#  'Pinus nigra',
#  'Pinus sylvestris',
#  'Sorbus aucuparia',
#  'Platanus acerifolia',
#  'Sophora japonica',
#  'Fraxinus excelsior',
#  'Zelkova serrata',
#  'Pinus nigra',
#  'Thuja',
#  'Cedrus atlantica',
#  'Tilia tomentosa',
#  'Tilia cordata',
#  'Prunus domestica',
#  'Acer campestre',
#  'Acer saccharinum',
#  'Robinia pseudoacacia',
#  'Liquidambar styraciflua',
#  'Tilia cordata',
#  'Sophora japonica',
#  'Platanus acerifolia',
#  'Acer pseudoplatanus',
#  'Picea abies',
#  'Acer platanoides',
#  'Celtis australis',
#  'Morus alba',
#  'Pinus sylvestris',
#  'Ginkgo biloba',
#  'Platanus acerifolia',
#  'Sorbus aria',
#  'Sophora japonica',
#  'Ginkgo biloba',
#  'Populus alba',
#  'Acer platanoides',
#  'Celtis australis',
#  'Cedrus atlantica',
#  'Corylus colurna',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Betula nigra',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula nigra',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer saccharinum',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Acer saccharinum',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Clerodendron tricotonum',
#  'Taxus baccata',
#  'Gleditsia triacanthos',
#  'Taxus baccata',
#  'Libocedrus decurrens',
#  'Quercus robur',
#  'Fraxinus excelsior',
#  'Lagerstroemia indica',
#  'Celtis australis',
#  'Acer negundo',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Alnus cordata',
#  'Acer platanoides',
#  'Taxodium distychum',
#  'Alnus cordata',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Amélanchier canadensis',
#  'Amélanchier canadensis',
#  'Amélanchier canadensis',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Quercus macrocarpa',
#  'Cupressus arizonica',
#  'Cercidiphyllum japonicum',
#  'Fraxinus excelsior',
#  'Acer saccharinum',
#  'Taxus baccata',
#  'Pyrus calleryana',
#  'Robinia pseudoacacia',
#  'Acer platanoides',
#  'Cedrus atlantica',
#  'Alnus cordata',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Liriodendron tulipifera',
#  'Taxus baccata',
#  'Magnolia grandiflora',
#  'Cedrus atlantica',
#  'Pyrus calleryana',
#  'Alnus cordata',
#  'Ilex aquifolium',
#  'Magnolia grandiflora',
#  'Pinus nigra',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Magnolia grandiflora',
#  'Alnus cordata',
#  'Picea abies',
#  'Tilia platyphyllos',
#  'Acer',
#  'Robinia pseudoacacia',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Picea abies',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Tilia platyphyllos',
#  'Fraxinus excelsior',
#  'Taxus baccata',
#  'Alnus cordata',
#  'Magnolia grandiflora',
#  'Malus floribunda',
#  'Malus floribunda',
#  'Malus floribunda',
#  'Fraxinus ornus',
#  'Cedrela sinensis',
#  'Cedrela sinensis',
#  'Prunus avium',
#  'Photinia villosa',
#  'Malus floribunda',
#  'Paulownia fortunei',
#  'Cedrela sinensis',
#  'Sorbus torminalis',
#  'Prunus padus',
#  'Prunus padus',
#  'Prunus padus',
#  'Paulownia fortunei',
#  'Sorbus torminalis',
#  'Paulownia fortunei',
#  'Prunus padus',
#  'Malus floribunda',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Platanus acerifolia',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Betula verrucosa',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Celtis australis',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Paulownia tomentosa',
#  'Pinus nigra',
#  'Robinia pseudoacacia',
#  'Pinus nigra',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Tetradium danielli',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Tilia tomentosa',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Fraxinus angustifolia',
#  'Pinus sylvestris',
#  'Fraxinus angustifolia',
#  'Ulmus minor',
#  'Ulmus minor',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Populus nigra',
#  'Acer platanoides',
#  'Populus nigra',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Ulmus minor',
#  'Ulmus minor',
#  'Liriodendron tulipifera',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus platanor',
#  'Platanus platanor',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Pinus nigra',
#  'Cupressus arizonica',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Pinus nigra',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Thuja occidentalis',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Pinus nigra',
#  'Acer platanoides',
#  'Betula verrucosa',
#  'Malus floribunda',
#  'Halesia carolina',
#  'Crataegus oxyacantha',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Cedrus deodara',
#  'Crataegus oxyacantha',
#  'Morus nigra',
#  'Morus nigra',
#  'Morus nigra',
#  'Aesculus hippocastanum',
#  'Aesculus hippocastanum',
#  'Prunus serrulata',
#  'Prunus serrulata',
#  'Prunus serrulata',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Acer',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liriodendron tulipifera',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Liquidambar styraciflua',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Ptelea trifoliata',
#  'Ptelea trifoliata',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Betula verrucosa',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Platanus acerifolia',
#  'Prunus serrulata',
#  'Quercus robur',
#  'Fraxinus angustifolia',
#  'Acer negundo',
#  'Celtis australis',
#  'Fraxinus americana',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Fraxinus excelsior',
#  'Acer pseudoplatanus',
#  'Chimonanthus praecox',
#  'Thuja occidentalis',
#  'Chimonanthus praecox',
#  'Chimonanthus praecox',
#  'Pyrus calleryana',
#  'Pyrus calleryana',
#  'Pyrus calleryana',
#  'Populus nigra',
#  'Populus nigra',
#  'Pinus nigra',
#  'Betula verrucosa',
#  'Populus nigra',
#  'Populus nigra',
#  'Picea abies',
#  'Populus nigra',
#  'Robinia pseudoacacia',
#  'Acer',
#  'Populus nigra',
#  'Tilia tomentosa',
#  'Pinus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Populus nigra',
#  'Betula verrucosa',
#  'Populus nigra',
#  'Betula verrucosa',
#  'Ulmus minor',
#  'Salix',
#  'Populus nigra',
#  'Pinus nigra',
#  'Populus nigra',
#  'Tilia mongolica',
#  'Alnus spaethii',
#  'Acer pseudoplatanus',
#  'Fraxinus americana',
#  'Ulmus resista',
#  'Fraxinus americana',
#  'Fraxinus americana',
#  'Acer pseudoplatanus',
#  'Acer pseudoplatanus',
#  'Alnus cordata',
#  'Alnus spaethii',
#  'Alnus cordata',
#  'Fraxinus americana',
#  'Fraxinus americana',
#  'Ulmus resista',
#  'Acer pseudoplatanus',
#  'Fraxinus americana',
#  'Alnus incana',
#  'Amélanchier ovalis',
#  'Alnus glutinosa',
#  'Acer platanoides',
#  'Carpinus betulus',
#  'Carpinus betulus',
#  'Betula alba',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Betula alba',
#  'Koelreuteria paniculata',
#  'Acer platanoides',
#  'Koelreuteria paniculata',
#  'Acer',
#  'Acer platanoides',
#  'Acer platanoides',
#  'Betula alba',
#  'Betula alba',
#  'Koelreuteria paniculata',
#  'Betula alba',
#  'Acer',
#  'Betula alba',
#  'Koelreuteria paniculata',
#  'Koelreuteria paniculata',
#  'Alnus cordata',
#  'Metasequoia glyptostroboides',
#  'Tilia mongolica',
#  'Prunus serrulata',
#  'Pinus nigra',
#  'Acer pseudoplatanus',
#  'Prunus serrulata',
#  'Malus sieboldii',
#  'Malus sieboldii',
#  'Cercis siliquastrum',
#  'Cercis siliquastrum',
#  'Acer ginnala',
#  'Pyrus amygdaliformis',
#  'Malus sieboldii',
#  'Pyrus amygdaliformis',
#  'Malus sieboldii',
#  'Prunus subhirtella',
#  'Prunus serrulata',
#  'Prunus serrulata',
#  'Malus sieboldii',
#  'Malus sieboldii',
#  'Acer campestre',
#  ...]

# %%
print(Counter(espèces_différentes).keys())
# Out:
# dict_keys(['Platanus', 'Ginkgo biloba', 'Salix', 'Liriodendron tulipifera', 'Catalpa bignonoides', 'Platanus acerifolia', 'Pyrus', 'Robinia pseudoacacia', 'Acer grosseri', 'Zelkova serrata', 'Parrotia persica', 'Fraxinus excelsior', 'Fagus sylvatica', 'Acer negundo', 'Magnolia grandiflora', 'Taxus baccata', 'Alnus cordata', 'Picea abies', 'Cupressus arizonica', 'Sequoiadendron giganteum', 'Pyrus calleryana', 'Pinus nigra', 'Betula verrucosa', 'Tilia platyphyllos', 'Acer pseudoplatanus', 'Tilia tomentosa', 'Acer platanoides', 'Cedrus deodara', 'Pinus sylvestris', 'Populus alba', 'Celtis australis', 'Tilia cordata', 'Populus nigra', 'Thuja', 'Sorbus aria', 'Sophora japonica', 'Acer cappadocicum', 'Acer campestre', 'Acer saccharinum', 'Liquidambar styraciflua', 'Prunus spinosa', 'Cedrus atlantica', 'Calocedrus decurrens', 'Pinus wallichiana', 'Prunus cerasus', 'Paulownia tomentosa', 'Tilia', 'Sorbus aucuparia', 'Gymnocladus dioicus', 'Ulmus minor', 'Corylus colurna', 'Prunus domestica', 'Morus alba', 'Betula nigra', 'Acer', 'Clerodendron tricotonum', 'Gleditsia triacanthos', 'Libocedrus decurrens', 'Quercus robur', 'Lagerstroemia indica', 'Taxodium distychum', 'Amélanchier canadensis', 'Quercus macrocarpa', 'Cercidiphyllum japonicum', 'Ilex aquifolium', 'Malus floribunda', 'Fraxinus ornus', 'Cedrela sinensis', 'Prunus avium', 'Photinia villosa', 'Paulownia fortunei', 'Sorbus torminalis', 'Prunus padus', 'Tetradium danielli', 'Fraxinus angustifolia', 'Platanus platanor', 'Thuja occidentalis', 'Koelreuteria paniculata', 'Halesia carolina', 'Crataegus oxyacantha', 'Morus nigra', 'Aesculus hippocastanum', 'Prunus serrulata', 'Ptelea trifoliata', 'Fraxinus americana', 'Chimonanthus praecox', 'Tilia mongolica', 'Alnus spaethii', 'Ulmus resista', 'Alnus incana', 'Amélanchier ovalis', 'Alnus glutinosa', 'Carpinus betulus', 'Betula alba', 'Metasequoia glyptostroboides', 'Malus sieboldii', 'Cercis siliquastrum', 'Acer ginnala', 'Pyrus amygdaliformis', 'Prunus subhirtella', 'Acer buergerianum', 'Cornus mas', 'Quercus cerris', 'Acer monspessulanum', 'Corylus avellana', 'Sorbus domestica', 'Juglans regia', 'Cedrus libani', 'Populus simonii', 'Salix viminalis', 'Salix triandra', 'Salix purpurea', 'Salix caprea', 'Pinus', 'Cupressus sempervirens', 'Quercus', 'Prunus', 'Pteroceltis tatarinowii', 'Crataegus lavallei', 'Populus tremula', 'Broussonetia papyrifera', 'Phellodendron amurense', 'Picea pungens', 'Thuja plicata', 'Betula pendula', 'Magnolia soulangeana', 'Quercus rubra', 'Prunus cerasifera', 'Crataegus splendens', 'Cupressocyparis leylandii', 'Salix alba', 'Prunus armeniaca', 'Cydonia oblonga', 'Pyrus communis', 'Prunus dulcis', 'Ficus carica', 'Fraxinus sieboldiana', 'Fraxinus pensylvanica', 'Quercus palustris', 'Morus', 'Acer rubrum', 'Malus tschonoskii', 'Ulmus campestre', 'Quercus castaneifolia', 'Cercis sinensis', 'Quercus heterophylla', 'Eleagnus angustifolia', 'Lonicera', 'Albizia jullibrissin', 'Pterocarya fraxinifolia', 'Cedrus', 'Davidia involucrata', 'Prunus laurocerasus', 'Fraxinus mandshurica', 'Cornus florida', 'Morus bombycis', 'Buxus sempervirens', 'Fraxinus quadrangulata', 'Aesculus carnea', 'Sorbus', 'Populus', 'Crataegus monogyna', 'Cladastris lutea', 'Chionanthus retusus', 'Fraxinus velutina', 'Malus perpetu', 'Amélanchier lamarckii', 'Syringa vulgaris', 'Platanus orientalis', 'Populus robusta', 'Quercus suber', 'Quercus ilex', 'Abies nordmaniana', 'Sterculia', 'Phillyrea latifolia', 'Fraxinus mariesii', 'Celtis sinensis', 'Malus domestica', 'Salix matsudana', 'Ailanthus altissima', 'Olea europaea', 'Juglans nigra', 'Sambucus nigra', 'Cupressus nooktensis', 'Acer capillipes', 'Picea omorika', 'Chamaecyparis lawsoniana', 'Fontanesia phillyreoides', 'Syringa amurensis', 'Pterostyrax hispida', 'Zelkova crenata', 'Fraxinus', 'Pterocarya stenoptera', 'Quercus frainetto', 'Robinia platanoides', 'Cornus controversa', 'Syringa persica', 'Magnolia kobus', 'Magnolia liliflora', 'Tilia henryana', 'Magnolia', 'Rhamnus alaternus', ...

# %%
print("Compter le nombre d'espèces différentes: ", len(Counter(espèces_différentes)))
# Out:
# Compter le nombre d'espèces différentes:  345

# %%
print(Counter(espèces_différentes))
# Out:
# Counter({'Platanus acerifolia': 4422, 'Acer pseudoplatanus': 1347, 'Pinus nigra': 1304, 'Carpinus betulus': 1282, 'Acer platanoides': 1130, 'Tilia tomentosa': 1000, 'Acer campestre': 845, 'Liquidambar styraciflua': 806, 'Acer': 805, 'Fraxinus excelsior': 776, 'Betula verrucosa': 712, 'Pinus sylvestris': 567, 'Alnus cordata': 550, 'Acer saccharinum': 507, 'Liriodendron tulipifera': 506, 'Populus nigra': 493, 'Aesculus hippocastanum': 432, 'Pyrus calleryana': 430, 'Prunus serrulata': 425, 'Sophora japonica': 422, 'Chamaecyparis lawsoniana': 370, 'Betula utilis': 361, 'Gleditsia triacanthos': 350, 'Cercis siliquastrum': 344, 'Magnolia grandiflora': 330, 'Cedrus atlantica': 316, 'Robinia pseudoacacia': 284, 'Koelreuteria paniculata': 271, 'Fagus sylvatica': 267, 'Tilia platyphyllos': 266, 'Tilia cordata': 257, 'Zelkova serrata': 231, 'Quercus cerris': 225, 'Pinus': 222, 'Populus robusta': 221, 'Picea abies': 206, 'Taxus baccata': 202, 'Acer cappadocicum': 198, 'Alnus glutinosa': 184, 'Acer negundo': 177, 'Fraxinus oxycarpa': 177, 'Fraxinus angustifolia': 165, 'Corylus colurna': 146, 'Prunus avium': 146, 'Ulmus minor': 144, 'Cupressus sempervirens': 140, 'Celtis australis': 134, 'Malus floribunda': 132, 'Populus alba': 120, 'Fraxinus ornus': 113, 'Fraxinus americana': 113, 'Prunus cerasifera': 112, 'Ginkgo biloba': 111, 'Quercus petraea': 101, 'Cupressocyparis leylandii': 100, 'Populus': 100, 'Betula alba': 97, 'Quercus robur': 95, 'Tilia': 94, 'Prunus padus': 92, 'Prunus': 90, 'Catalpa bignonoides': 89, 'Tetradium danielli': 88, 'Platanus orientalis': 88, 'Tilia americana': 88, 'Platanus platanor': 84, 'Metasequoia glyptostroboides': 81, 'Ailanthus altissima': 80, 'Cedrus deodara': 78, 'Paulownia tomentosa': 78, 'Alnus spaethii': 78, 'Acer monspessulanum': 76, 'Amélanchier canadensis': 70, 'Platanus': 69, 'Albizia jullibrissin': 67, 'Quercus castaneifolia': 63, 'Malus domestica': 63, 'Cupressus arizonica': 60, 'Quercus': 59, 'Salix': 56, 'Parrotia persica': 54, 'Fraxinus velutina': 54, 'Acer freemanii': 52, 'Lagerstroemia indica': 50, 'Acer ginnala': 49, 'Salix alba': 48, 'Libocedrus decurrens': 47, 'Cedrela sinensis': 46, 'Pterocarya fraxinifolia': 46, 'Cladastris lutea': 45, 'Celtis sinensis': 45, 'Sorbus aria': 44, 'Crataegus oxyacantha': 44, 'Ostrya carpinifolia': 44, 'Magnolia soulangeana': 42, 'Fraxinus': 39, 'Morus nigra': 38, 'Juglans nigra': 38, 'Betula nigra': 34, 'Pyrus communis': 34, 'Sambucus nigra': 33, 'Tilia henryana': 33, 'Chionanthus retusus': 31, 'Syringa vulgaris': 31, 'Quercus frainetto': 31, 'Prunus cerasus': 28, 'Juglans regia': 28, 'Crataegus': 27, 'Morus alba': 26, 'Quercus rubra': 25, 'Morus bombycis': 25, 'Thuja': 24, 'Ilex aquifolium': 24, 'Tilia mongolica': 24, 'Ulmus resista': 24, 'Corylus avellana': 24, 'Fraxinus pensylvanica': 24, 'Malus perpetu': 24, 'Paulownia fortunei': 23, 'Broussonetia papyrifera': 23, 'Betula papyrifera': 23, 'Acer rubrum': 22, 'Magnolia kobus': 22, 'Trachycarpus fortunei': 22, 'Prunus domestica': 21, 'Pinus wallichiana': 20, 'Acer buergerianum': 20, 'Aesculus carnea': 20, 'Abies nordmaniana': 20, 'Prunus spinosa': 19, 'Fraxinus sieboldiana': 19, 'Eleagnus angustifolia': 19, 'Crataegus monogyna': 19, 'Thuja plicata': 18, 'Ficus carica': 18, 'Fraxinus mandshurica': 18, 'Picea orientalis': 18, 'Prunus subhirtella': 17, 'Populus tremula': 17, 'Betula pendula': 17, 'Quercus palustris': 17, 'Buxus sempervirens': 17, 'Quercus suber': 17, 'Ulmus campestre': 16, 'Sorbus torminalis': 15, 'Acer capillipes': 15, 'Amélanchier lamarckii': 14, 'Carpinus orientalis': 14, 'Alnus incana': 13, 'Phellodendron amurense': 13, 'Picea pungens': 13, 'Malus tschonoskii': 13, 'Quercus ilex': 13, 'Malus sieboldii': 12, 'Pteroceltis tatarinowii': 12, 'Sorbus': 12, 'Pyrus salicifolia': 12, 'Laburnum anagynoides': 12, 'Prunus yedoensis': 12, 'Morus': 11, 'Ulmus': 11, 'Cotinus coggygria': 11, 'Ulmus glabra': 11, 'Pyrus nivalis': 11, 'Crataegus laevigata': 11, 'Photinia villosa': 10, 'Pyrus amygdaliformis':  ...

# %% [markdown]
# ### ● En utilisant la structure de données Dict compter le nombre de représentants de chaque genre botanique:

# %% [markdown]
# #### ○ Quel est le genre botanique le plus représenté?

# %%
Counter(list_genres)
# Out:
# Counter({'Acer': 5276,
#          'Platanus': 4663,
#          'Pinus': 2118,
#          'Tilia': 1770,
#          'Fraxinus': 1506,
#          'Carpinus': 1296,
#          'Betula': 1247,
#          'Prunus': 996,
#          'Populus': 966,
#          'Alnus': 826,
#          'Liquidambar': 809,
#          'Quercus': 677,
#          'Liriodendron': 507,
#          'Pyrus': 501,
#          'Aesculus': 459,
#          'Sophora': 426,
#          'Magnolia': 409,
#          'Cedrus': 407,
#          'Chamaecyparis': 373,
#          'Gleditsia': 352,
#          'Cercis': 351,
#          'Robinia': 287,
#          'Koelreuteria': 271,
#          'Fagus': 267,
#          'Malus': 262,
#          'Picea': 252,
#          'Zelkova': 233,
#          'Ulmus': 210,
#          'Cupressus': 203,
#          'Taxus': 202,
#          'Celtis': 193,
#          'Corylus': 174,
#          'Salix': 143,
#          'Ginkgo': 111,
#          'Crataegus': 108,
#          'Paulownia': 101,
#          'Morus': 100,
#          'Cupressocyparis': 100,
#          'Amélanchier': 96,
#          'Catalpa': 89,
#          'Sorbus': 88,
#          'Tetradium': 88,
#          'Metasequoia': 81,
#          'Ailanthus': 80,
#          'Albizia': 67,
#          'Juglans': 66,
#          'Parrotia': 54,
#          'Pterocarya': 52,
#          'Lagerstroemia': 50,
#          'Thuja': 48,
#          'Libocedrus': 47,
#          'Cedrela': 46,
#          'Cladastris': 45,
#          'Ostrya': 44,
#          'Syringa': 41,
#          'Chionanthus': 33,
#          'Sambucus': 33,
#          'Abies': 28,
#          'Ilex': 24,
#          'Cornus': 23,
#          'Broussonetia': 23,
#          'Trachycarpus': 22,
#          'Ficus': 19,
#          'Eleagnus': 19,
#          'Buxus': 17,
#          'Diospyros': 17,
#          'Sequoiadendron': 14,
#          'Phellodendron': 13,
#          'Laburnum': 13,
#          'Pteroceltis': 12,
#          'Cydonia': 11,
#          'Cotinus': 11,
#          'Photinia': 10,
#          'Gymnocladus': 9,
#          'Taxodium': 9,
#          'Halesia': 9,
#          'Cercidiphyllum': 7,
#          'Davidia': 7,
#          'Mespilus': 7,
#          'Pistacia': 7,
#          'Rhus': 7,
#          'Lonicera': 6,
#          'Pterostyrax': 6,
#          'Clerodendron': 5,
#          'Olea': 5,
#          'Maclura': 5,
#          'Ligustrum': 5,
#          'Larix': 5,
#          'Calocedrus': 4,
#          'Fontanesia': 4,
#          'Juniperus': 4,
#          'Chitalpa': 4,
#          'Ptelea': 3,
#          'Chimonanthus': 3,
#          'Phillyrea': 3,
#          'Eriobotrya': 3,
#          'Cephalotaxus': 3,
#          'Styrax': 3,
#          'Punica': 3,
#          'Araucaria': 2,
#          'Cryptomeria': 2,
#          'Hovenia': 2,
#          'Sterculia': 1,
#          'Rhamnus': 1,
#          'Castanea': 1,
#          'Eucalyptus': 1,
#          'Staphylea': 1,
#          'Sequoia': 1,
#          'Nyssa': 1,
#          'Sciadopitys': 1,
#          'Sorbopyrus': 1,
#          'Poncinos': 1})

# %%
key_max = max(zip(Counter(list_genres).values(), Counter(list_genres).keys()))[1]
value_max = max(zip(Counter(list_genres).values(), Counter(list_genres).keys()))[0]
print(f"Le plus grand genre botanique compte est le {key_max} avec {value_max} entrées")
# Out:
# Le plus grand genre botanique compte est le Acer avec 5276 entrées

# %% [markdown]
# #### ○ Listez tous les représentants uniques de leurs genre botanique

# %%
list_genres_uniques = []

for k, v in Counter(list_genres).items():

    list_genres_uniques.append(k)

list_genres_uniques
# Out:
# ['Platanus',
#  'Ginkgo',
#  'Salix',
#  'Liriodendron',
#  'Catalpa',
#  'Pyrus',
#  'Robinia',
#  'Acer',
#  'Zelkova',
#  'Parrotia',
#  'Fraxinus',
#  'Fagus',
#  'Magnolia',
#  'Taxus',
#  'Alnus',
#  'Picea',
#  'Cupressus',
#  'Sequoiadendron',
#  'Pinus',
#  'Betula',
#  'Tilia',
#  'Cedrus',
#  'Populus',
#  'Celtis',
#  'Thuja',
#  'Sorbus',
#  'Sophora',
#  'Liquidambar',
#  'Prunus',
#  'Calocedrus',
#  'Paulownia',
#  'Gymnocladus',
#  'Ulmus',
#  'Corylus',
#  'Morus',
#  'Clerodendron',
#  'Gleditsia',
#  'Libocedrus',
#  'Quercus',
#  'Lagerstroemia',
#  'Taxodium',
#  'Amélanchier',
#  'Cercidiphyllum',
#  'Ilex',
#  'Malus',
#  'Cedrela',
#  'Photinia',
#  'Tetradium',
#  'Koelreuteria',
#  'Halesia',
#  'Crataegus',
#  'Aesculus',
#  'Ptelea',
#  'Chimonanthus',
#  'Carpinus',
#  'Metasequoia',
#  'Cercis',
#  'Cornus',
#  'Juglans',
#  'Pteroceltis',
#  'Broussonetia',
#  'Phellodendron',
#  'Cupressocyparis',
#  'Cydonia',
#  'Ficus',
#  'Eleagnus',
#  'Lonicera',
#  'Albizia',
#  'Pterocarya',
#  'Davidia',
#  'Buxus',
#  'Cladastris',
#  'Chionanthus',
#  'Syringa',
#  'Abies',
#  'Sterculia',
#  'Phillyrea',
#  'Ailanthus',
#  'Olea',
#  'Sambucus',
#  'Chamaecyparis',
#  'Fontanesia',
#  'Pterostyrax',
#  'Rhamnus',
#  'Diospyros',
#  'Laburnum',
#  'Ostrya',
#  'Juniperus',
#  'Araucaria',
#  'Cryptomeria',
#  'Eriobotrya',
#  'Cephalotaxus',
#  'Mespilus',
#  'Pistacia',
#  'Cotinus',
#  'Trachycarpus',
#  'Rhus',
#  'Castanea',
#  'Maclura',
#  'Hovenia',
#  'Styrax',
#  'Eucalyptus',
#  'Staphylea',
#  'Sequoia',
#  'Chitalpa',
#  'Ligustrum',
#  'Larix',
#  'Nyssa',
#  'Punica',
#  'Sciadopitys',
#  'Sorbopyrus',
#  'Poncinos']

# %% [markdown]
# #### ○ Classer tous les genres botaniques en fonction de leur nombre (ordre décroissant)

# %%
Counter(list_genres)
# Out:
# Counter({'Acer': 5276,
#          'Platanus': 4663,
#          'Pinus': 2118,
#          'Tilia': 1770,
#          'Fraxinus': 1506,
#          'Carpinus': 1296,
#          'Betula': 1247,
#          'Prunus': 996,
#          'Populus': 966,
#          'Alnus': 826,
#          'Liquidambar': 809,
#          'Quercus': 677,
#          'Liriodendron': 507,
#          'Pyrus': 501,
#          'Aesculus': 459,
#          'Sophora': 426,
#          'Magnolia': 409,
#          'Cedrus': 407,
#          'Chamaecyparis': 373,
#          'Gleditsia': 352,
#          'Cercis': 351,
#          'Robinia': 287,
#          'Koelreuteria': 271,
#          'Fagus': 267,
#          'Malus': 262,
#          'Picea': 252,
#          'Zelkova': 233,
#          'Ulmus': 210,
#          'Cupressus': 203,
#          'Taxus': 202,
#          'Celtis': 193,
#          'Corylus': 174,
#          'Salix': 143,
#          'Ginkgo': 111,
#          'Crataegus': 108,
#          'Paulownia': 101,
#          'Morus': 100,
#          'Cupressocyparis': 100,
#          'Amélanchier': 96,
#          'Catalpa': 89,
#          'Sorbus': 88,
#          'Tetradium': 88,
#          'Metasequoia': 81,
#          'Ailanthus': 80,
#          'Albizia': 67,
#          'Juglans': 66,
#          'Parrotia': 54,
#          'Pterocarya': 52,
#          'Lagerstroemia': 50,
#          'Thuja': 48,
#          'Libocedrus': 47,
#          'Cedrela': 46,
#          'Cladastris': 45,
#          'Ostrya': 44,
#          'Syringa': 41,
#          'Chionanthus': 33,
#          'Sambucus': 33,
#          'Abies': 28,
#          'Ilex': 24,
#          'Cornus': 23,
#          'Broussonetia': 23,
#          'Trachycarpus': 22,
#          'Ficus': 19,
#          'Eleagnus': 19,
#          'Buxus': 17,
#          'Diospyros': 17,
#          'Sequoiadendron': 14,
#          'Phellodendron': 13,
#          'Laburnum': 13,
#          'Pteroceltis': 12,
#          'Cydonia': 11,
#          'Cotinus': 11,
#          'Photinia': 10,
#          'Gymnocladus': 9,
#          'Taxodium': 9,
#          'Halesia': 9,
#          'Cercidiphyllum': 7,
#          'Davidia': 7,
#          'Mespilus': 7,
#          'Pistacia': 7,
#          'Rhus': 7,
#          'Lonicera': 6,
#          'Pterostyrax': 6,
#          'Clerodendron': 5,
#          'Olea': 5,
#          'Maclura': 5,
#          'Ligustrum': 5,
#          'Larix': 5,
#          'Calocedrus': 4,
#          'Fontanesia': 4,
#          'Juniperus': 4,
#          'Chitalpa': 4,
#          'Ptelea': 3,
#          'Chimonanthus': 3,
#          'Phillyrea': 3,
#          'Eriobotrya': 3,
#          'Cephalotaxus': 3,
#          'Styrax': 3,
#          'Punica': 3,
#          'Araucaria': 2,
#          'Cryptomeria': 2,
#          'Hovenia': 2,
#          'Sterculia': 1,
#          'Rhamnus': 1,
#          'Castanea': 1,
#          'Eucalyptus': 1,
#          'Staphylea': 1,
#          'Sequoia': 1,
#          'Nyssa': 1,
#          'Sciadopitys': 1,
#          'Sorbopyrus': 1,
#          'Poncinos': 1})

# %% [markdown]
# #### ○ Quelle est la proportion du genre botanique le plus représenté parmi tous les genres?

# %%
total = 0

for k, v in Counter(list_genres).items():

    total += v

value_max = max(zip(Counter(list_genres).values(), Counter(list_genres).keys()))[0]
key_max = max(zip(Counter(list_genres).values(), Counter(list_genres).keys()))[1]

proportion = round((value_max / total), 2)

print(f"Le genre botanique le plus représenté est {key_max}, dont la proportion dans le total est de {proportion}")
# Out:
# Le genre botanique le plus représenté est Acer, dont la proportion dans le total est de 0.17

# %%
total
# Out:
# 30728

# %% [markdown]
# #### Quelle est la proportion de chacun des genres botaniques par rapport au total?

# %%
total = 0
proportions_genres = {}

for k, v in Counter(list_genres).items():

    total += v

for k, v in Counter(list_genres).items():

    prop = round((v / total), 5)

    if k not in proportions_genres:
        proportions_genres[k] = []
    proportions_genres[k].append(prop)

proportions_genres
# Out:
# {'Platanus': [0.15175],
#  'Ginkgo': [0.00361],
#  'Salix': [0.00465],
#  'Liriodendron': [0.0165],
#  'Catalpa': [0.0029],
#  'Pyrus': [0.0163],
#  'Robinia': [0.00934],
#  'Acer': [0.1717],
#  'Zelkova': [0.00758],
#  'Parrotia': [0.00176],
#  'Fraxinus': [0.04901],
#  'Fagus': [0.00869],
#  'Magnolia': [0.01331],
#  'Taxus': [0.00657],
#  'Alnus': [0.02688],
#  'Picea': [0.0082],
#  'Cupressus': [0.00661],
#  'Sequoiadendron': [0.00046],
#  'Pinus': [0.06893],
#  'Betula': [0.04058],
#  'Tilia': [0.0576],
#  'Cedrus': [0.01325],
#  'Populus': [0.03144],
#  'Celtis': [0.00628],
#  'Thuja': [0.00156],
#  'Sorbus': [0.00286],
#  'Sophora': [0.01386],
#  'Liquidambar': [0.02633],
#  'Prunus': [0.03241],
#  'Calocedrus': [0.00013],
#  'Paulownia': [0.00329],
#  'Gymnocladus': [0.00029],
#  'Ulmus': [0.00683],
#  'Corylus': [0.00566],
#  'Morus': [0.00325],
#  'Clerodendron': [0.00016],
#  'Gleditsia': [0.01146],
#  'Libocedrus': [0.00153],
#  'Quercus': [0.02203],
#  'Lagerstroemia': [0.00163],
#  'Taxodium': [0.00029],
#  'Amélanchier': [0.00312],
#  'Cercidiphyllum': [0.00023],
#  'Ilex': [0.00078],
#  'Malus': [0.00853],
#  'Cedrela': [0.0015],
#  'Photinia': [0.00033],
#  'Tetradium': [0.00286],
#  'Koelreuteria': [0.00882],
#  'Halesia': [0.00029],
#  'Crataegus': [0.00351],
#  'Aesculus': [0.01494],
#  'Ptelea': [0.0001],
#  'Chimonanthus': [0.0001],
#  'Carpinus': [0.04218],
#  'Metasequoia': [0.00264],
#  'Cercis': [0.01142],
#  'Cornus': [0.00075],
#  'Juglans': [0.00215],
#  'Pteroceltis': [0.00039],
#  'Broussonetia': [0.00075],
#  'Phellodendron': [0.00042],
#  'Cupressocyparis': [0.00325],
#  'Cydonia': [0.00036],
#  'Ficus': [0.00062],
#  'Eleagnus': [0.00062],
#  'Lonicera': [0.0002],
#  'Albizia': [0.00218],
#  'Pterocarya': [0.00169],
#  'Davidia': [0.00023],
#  'Buxus': [0.00055],
#  'Cladastris': [0.00146],
#  'Chionanthus': [0.00107],
#  'Syringa': [0.00133],
#  'Abies': [0.00091],
#  'Sterculia': [3e-05],
#  'Phillyrea': [0.0001],
#  'Ailanthus': [0.0026],
#  'Olea': [0.00016],
#  'Sambucus': [0.00107],
#  'Chamaecyparis': [0.01214],
#  'Fontanesia': [0.00013],
#  'Pterostyrax': [0.0002],
#  'Rhamnus': [3e-05],
#  'Diospyros': [0.00055],
#  'Laburnum': [0.00042],
#  'Ostrya': [0.00143],
#  'Juniperus': [0.00013],
#  'Araucaria': [7e-05],
#  'Cryptomeria': [7e-05],
#  'Eriobotrya': [0.0001],
#  'Cephalotaxus': [0.0001],
#  'Mespilus': [0.00023],
#  'Pistacia': [0.00023],
#  'Cotinus': [0.00036],
#  'Trachycarpus': [0.00072],
#  'Rhus': [0.00023],
#  'Castanea': [3e-05],
#  'Maclura': [0.00016],
#  'Hovenia': [7e-05],
#  'Styrax': [0.0001],
#  'Eucalyptus': [3e-05],
#  'Staphylea': [3e-05],
#  'Sequoia': [3e-05],
#  'Chitalpa': [0.00013],
#  'Ligustrum': [0.00016],
#  'Larix': [0.00016],
#  'Nyssa': [3e-05],
#  'Punica': [0.0001],
#  'Sciadopitys': [3e-05],
#  'Sorbopyrus': [3e-05],
#  'Poncinos': [3e-05]}

# %%
prop_total = []

for k, v in Counter(proportions_genres).items():

    prop_total.append(v)

prop_total = list(itertools.chain.from_iterable(prop_total))

somme = 0

for j in prop_total:

    somme += j

round(somme, 5)
# Out:
# 0.99997

# %%
with open('../data/proportion_genres.csv', 'w', newline='') as csv_file:

    header = ['Genre', 'Proportion']

    writer = csv.DictWriter(csv_file, fieldnames=header)

    writer.writeheader()

    for key in proportions_genres:
        writer.writerow({'Genre': key, 'Proportion': proportions_genres[key]})

# %% [markdown]
# #### ○ Les objectifs de la Métro sont-ils respectés en termes de diversité?

# %%
key_max = max(zip(Counter(espèces_différentes).values(), Counter(espèces_différentes).keys()))[1]
value_max = max(zip(Counter(espèces_différentes).values(), Counter(espèces_différentes).keys()))[0]
print(f"Le plus grand espèce compte est le {key_max} avec {value_max} entrées")
# Out:
# Le plus grand espèce compte est le Platanus acerifolia avec 4422 entrées

# %%
total = 0

for k, v in Counter(espèces_différentes).items():

    total += v

value_max = max(zip(Counter(espèces_différentes).values(), Counter(espèces_différentes).keys()))[0]
key_max = max(zip(Counter(espèces_différentes).values(), Counter(espèces_différentes).keys()))[1]

proportion = round((value_max / total), 2)

print(f"Le espèce botanique le plus représenté est {key_max}, dont la proportion dans le total est de {proportion}")
# Out:
# Le espèce botanique le plus représenté est Platanus acerifolia, dont la proportion dans le total est de 0.14

# %% [markdown]
# #### Il y a plus de 10% d'espèce Pltanus Acerifolia
#
# #### mais, il n'y a pas plus de 20% d'un genre

# %%
total_esp = 0
proportions_especes = {}

for k, v in Counter(espèces_différentes).items():

    total_esp += v

for k, v in Counter(espèces_différentes).items():

    prop_esp = round((v / total_esp), 5)

    if k not in proportions_especes:
        proportions_especes[k] = []
    proportions_especes[k].append(prop_esp)

proportions_especes
# Out:
# {'Platanus': [0.00225],
#  'Ginkgo biloba': [0.00361],
#  'Salix': [0.00182],
#  'Liriodendron tulipifera': [0.01647],
#  'Catalpa bignonoides': [0.0029],
#  'Platanus acerifolia': [0.14391],
#  'Pyrus': [0.0001],
#  'Robinia pseudoacacia': [0.00924],
#  'Acer grosseri': [0.0001],
#  'Zelkova serrata': [0.00752],
#  'Parrotia persica': [0.00176],
#  'Fraxinus excelsior': [0.02525],
#  'Fagus sylvatica': [0.00869],
#  'Acer negundo': [0.00576],
#  'Magnolia grandiflora': [0.01074],
#  'Taxus baccata': [0.00657],
#  'Alnus cordata': [0.0179],
#  'Picea abies': [0.0067],
#  'Cupressus arizonica': [0.00195],
#  'Sequoiadendron giganteum': [0.00026],
#  'Pyrus calleryana': [0.01399],
#  'Pinus nigra': [0.04244],
#  'Betula verrucosa': [0.02317],
#  'Tilia platyphyllos': [0.00866],
#  'Acer pseudoplatanus': [0.04384],
#  'Tilia tomentosa': [0.03254],
#  'Acer platanoides': [0.03677],
#  'Cedrus deodara': [0.00254],
#  'Pinus sylvestris': [0.01845],
#  'Populus alba': [0.00391],
#  'Celtis australis': [0.00436],
#  'Tilia cordata': [0.00836],
#  'Populus nigra': [0.01604],
#  'Thuja': [0.00078],
#  'Sorbus aria': [0.00143],
#  'Sophora japonica': [0.01373],
#  'Acer cappadocicum': [0.00644],
#  'Acer campestre': [0.0275],
#  'Acer saccharinum': [0.0165],
#  'Liquidambar styraciflua': [0.02623],
#  'Prunus spinosa': [0.00062],
#  'Cedrus atlantica': [0.01028],
#  'Calocedrus decurrens': [0.00013],
#  'Pinus wallichiana': [0.00065],
#  'Prunus cerasus': [0.00091],
#  'Paulownia tomentosa': [0.00254],
#  'Tilia': [0.00306],
#  'Sorbus aucuparia': [0.00016],
#  'Gymnocladus dioicus': [0.00029],
#  'Ulmus minor': [0.00469],
#  'Corylus colurna': [0.00475],
#  'Prunus domestica': [0.00068],
#  'Morus alba': [0.00085],
#  'Betula nigra': [0.00111],
#  'Acer': [0.0262],
#  'Clerodendron tricotonum': [0.00016],
#  'Gleditsia triacanthos': [0.01139],
#  'Libocedrus decurrens': [0.00153],
#  'Quercus robur': [0.00309],
#  'Lagerstroemia indica': [0.00163],
#  'Taxodium distychum': [0.00029],
#  'Amélanchier canadensis': [0.00228],
#  'Quercus macrocarpa': [3e-05],
#  'Cercidiphyllum japonicum': [0.0002],
#  'Ilex aquifolium': [0.00078],
#  'Malus floribunda': [0.0043],
#  'Fraxinus ornus': [0.00368],
#  'Cedrela sinensis': [0.0015],
#  'Prunus avium': [0.00475],
#  'Photinia villosa': [0.00033],
#  'Paulownia fortunei': [0.00075],
#  'Sorbus torminalis': [0.00049],
#  'Prunus padus': [0.00299],
#  'Tetradium danielli': [0.00286],
#  'Fraxinus angustifolia': [0.00537],
#  'Platanus platanor': [0.00273],
#  'Thuja occidentalis': [0.0002],
#  'Koelreuteria paniculata': [0.00882],
#  'Halesia carolina': [0.00026],
#  'Crataegus oxyacantha': [0.00143],
#  'Morus nigra': [0.00124],
#  'Aesculus hippocastanum': [0.01406],
#  'Prunus serrulata': [0.01383],
#  'Ptelea trifoliata': [0.0001],
#  'Fraxinus americana': [0.00368],
#  'Chimonanthus praecox': [0.0001],
#  'Tilia mongolica': [0.00078],
#  'Alnus spaethii': [0.00254],
#  'Ulmus resista': [0.00078],
#  'Alnus incana': [0.00042],
#  'Amélanchier ovalis': [0.00026],
#  'Alnus glutinosa': [0.00599],
#  'Carpinus betulus': [0.04172],
#  'Betula alba': [0.00316],
#  'Metasequoia glyptostroboides': [0.00264],
#  'Malus sieboldii': [0.00039],
#  'Cercis siliquastrum': [0.0112],
#  'Acer ginnala': [0.00159],
#  'Pyrus amygdaliformis': [0.00033],
#  'Prunus subhirtella': [0.00055],
#  'Acer buergerianum': [0.00065],
#  'Cornus mas': [0.00033],
#  'Quercus cerris': [0.00732],
#  'Acer monspessulanum': [0.00247],
#  'Corylus avellana': [0.00078],
#  'Sorbus domestica': [0.00013],
#  'Juglans regia': [0.00091],
#  'Cedrus libani': [0.00026],
#  'Populus simonii': [0.00026],
#  'Salix viminalis': [0.00023],
#  'Salix triandra': [0.00016],
#  'Salix purpurea': [0.00016],
#  'Salix caprea': [0.00013],
#  'Pinus': [0.00722],
#  'Cupressus sempervirens': [0.00456],
#  'Quercus': [0.00192],
#  'Prunus': [0.00293],
#  'Pteroceltis tatarinowii': [0.00039],
#  'Crataegus lavallei': [0.00013],
#  'Populus tremula': [0.00055],
#  'Broussonetia papyrifera': [0.00075],
#  'Phellodendron amurense': [0.00042],
#  'Picea pungens': [0.00042],
#  'Thuja plicata': [0.00059],
#  'Betula pendula': [0.00055],
#  'Magnolia soulangeana': [0.00137],
#  'Quercus rubra': [0.00081],
#  'Prunus cerasifera': [0.00364],
#  'Crataegus splendens': [3e-05],
#  'Cupressocyparis leylandii': [0.00325],
#  'Salix alba': [0.00156],
#  'Prunus armeniaca': [7e-05],
#  'Cydonia oblonga': [0.00033],
#  'Pyrus communis': [0.00111],
#  'Prunus dulcis': [0.0002],
#  'Ficus carica': [0.00059],
#  'Fraxinus sieboldiana': [0.00062],
#  'Fraxinus pensylvanica': [0.00078],
#  'Quercus palustris': [0.00055],
#  'Morus': [0.00036],
#  'Acer rubrum': [0.00072],
#  'Malus tschonoskii': [0.00042],
#  'Ulmus campestre': [0.00052],
#  'Quercus castaneifolia': [0.00205],
#  'Cercis sinensis': [3e-05],
#  'Quercus heterophylla': [3e-05],
#  'Eleagnus angustifolia': [0.00062],
#  'Lonicera': [0.0001],
#  'Albizia jullibrissin': [0.00218],
#  'Pterocarya fraxinifolia': [0.0015],
#  'Cedrus': [0.00013],
#  'Davidia involucrata': [0.00023],
#  'Prunus laurocerasus': [0.00029],
#  'Fraxinus mandshurica': [0.00059],
#  'Cornus florida': [0.0002],
#  'Morus bombycis': [0.00081],
#  'Buxus sempervirens': [0.00055],
#  'Fraxinus quadrangulata': [3e-05],
#  'Aesculus carnea': [0.00065],
#  'Sorbus': [0.00039],
#  'Populus': [0.00325],
#  'Crataegus monogyna': [0.00062],
#  'Cladastris lutea': [0.00146],
#  'Chionanthus retusus': [0.00101],
#  'Fraxinus velutina': [0.00176],
#  'Malus perpetu': [0.00078],
#  'Amélanchier lamarckii': [0.00046],
#  'Syringa vulgaris': [0.00101],
#  'Platanus orientalis': [0.00286],
#  'Populus robusta': [0.00719],
#  'Quercus suber': [0.00055],
#  'Quercus ilex': [0.00042],
#  'Abies nordmaniana': [0.00065],
#  'Sterculia': [3e-05],
#  'Phillyrea latifolia': [0.0001],
#  'Fraxinus mariesii': [0.00023],
#  'Celtis sinensis': [0.00146],
#  'Malus domestica': [0.00205],
#  'Salix matsudana': [0.0002],
#  'Ailanthus altissima': [0.0026],
#  'Olea europaea': [0.00016],
#  'Juglans nigra': [0.00124],
#  'Sambucus nigra': [0.00107],
#  'Cupressus nooktensis': [0.0001],
#  'Acer capillipes': [0.00049],
#  'Picea omorika': [0.00013],
#  'Chamaecyparis lawsoniana': [0.01204],
#  'Fontanesia phillyreoides': [0.00013],
#  'Syringa amurensis': [0.00026],
#  'Pterostyrax hispida': [0.0002],
#  'Zelkova crenata': [7e-05],
#  'Fraxinus': [0.00127],
#  'Pterocarya stenoptera': [0.0002],
#  'Quercus frainetto': [0.00101],
#  'Robinia platanoides': [3e-05],
#  'Cornus controversa': [0.00023],
#  'Syringa persica': [7e-05],
#  'Magnolia kobus': [0.00072],
#  'Magnolia liliflora': [3e-05],
#  'Tilia henryana': [0.00107],
#  'Magnolia': [0.00026],
#  'Rhamnus alaternus': [3e-05],
#  'Abies concolor': [0.00016],
#  'Quercus petraea': [0.00329],
#  'Betula utilis': [0.01175],
#  'Acer freemanii': [0.00169],
#  'Salix babylonica': [0.00023],
#  'Acer opalus': [3e-05],
#  'Tilia americana': [0.00286],
#  'Ulmus': [0.00036],
#  'Diospyros': [7e-05],
#  'Laburnum watereri': [3e-05],
#  'Tilia euchlora': [7e-05],
#  'Quercus coccinea': [3e-05],
#  'Prunus incisa': [3e-05],
#  'Ostrya carpinifolia': [0.00143],
#  'Juniperus': [7e-05],
#  'Diospyros lotus': [0.00026],
#  'Crataegus': [0.00088],
#  'Chamaecyparis formonensis': [3e-05],
#  'Prunus lusitanica': [0.0002],
#  'Araucaria exelsa': [7e-05],
#  'Prunus tomentosa': [3e-05],
#  'Cryptomeria japonica': [7e-05],
#  'Betula papyrifera': [0.00075],
#  'Aesculus parviflora': [7e-05],
#  'Quercus salicifolia': [0.00029],
#  'Acer nikoense': [7e-05],
#  'Acer griseum': [0.00016],
#  'Sorbus latifolia': [0.0001],
#  'Prunus persica': [0.0001],
#  'Eriobotrya  japonica': [0.0001],
#  'Malus baccata': [0.00029],
#  'Magnolia stellata': [7e-05],
#  'Abies pinsapo': [7e-05],
#  'Chamaecyparis pisifera': [3e-05],
#  'Pinus strobus': [3e-05],
#  'Cephalotaxus harringtonia': [0.0001],
#  'Acer palmatum': [7e-05],
#  'Mespilus germanica': [0.00023],
#  'Pistacia chinensis': [0.00023],
#  'Alnus': [3e-05],
#  'Robinia': [3e-05],
#  'Malus': [7e-05],
#  'Populus lasiocarpa': [3e-05],
#  'Amélanchier alnifolia': [0.0001],
#  'Tilia europaea': [0.0002],
#  'Sequoiadendron sempervirens': [0.0002],
#  'Fraxinus oxycarpa': [0.00576],
#  'Cotinus coggygria': [0.00036],
#  'Liriodendron': [3e-05],
#  'Picea': [0.00023],
#  'Salix rosmarinifolia': [7e-05],
#  'Corylus': [0.00013],
#  'Cercis chinensis': [0.00013],
#  'Ulmus carpinifolia': [7e-05],
#  'Aesculus pavia': [0.0001],
#  'Trachycarpus fortunei': [0.00072],
#  'Salix sepulcralis': [0.0001],
#  'Pyrus salicifolia': [0.00039],
#  'Rhus typhina': [0.0002],
#  'Populus italica': [0.0002],
#  'Diospyros kaki': [3e-05],
#  'Prunus amygdalus': [7e-05],
#  'Acer heldreichii': [7e-05],
#  'Pinus pinea': [7e-05],
#  'Ulmus glabra': [0.00036],
#  'Robinia altissima': [3e-05],
#  'Castanea sativa': [3e-05],
#  'Cercis canadensis': [7e-05],
#  'Pyrus elaeagnifolia': [3e-05],
#  'Malus hupehensis': [0.0001],
#  'Maclura pomifera': [0.00016],
#  'Laburnum anagynoides': [0.00039],
#  'Malus royalty': [3e-05],
#  'Rhus thyphina': [3e-05],
#  'Acer tartarica': [7e-05],
#  'Ficus': [3e-05],
#  'Pyrus nivalis': [0.00036],
#  'Cydonia vulgaris': [3e-05],
#  'Hovenia dulcis': [7e-05],
#  'Carpinus orientalis': [0.00046],
#  'Quercus falcata': [0.0001],
#  'Crataegus laevigata': [0.00036],
#  'Amélanchier laevis': [3e-05],
#  'Quercus phellos': [3e-05],
#  'Abies koreana': [3e-05],
#  'Quercus myrsinifolia': [0.00013],
#  'Styrax japonica': [0.0001],
#  'Eucalyptus gunii': [3e-05],
#  'Acer triflorum': [7e-05],
#  'Celtis': [0.0002],
#  'Ulmus parvifolia': [3e-05],
#  'Chionanthus virginiacus': [7e-05],
#  'Acer zoeschense': [3e-05],
#  'Picea exelsa': [0.00013],
#  'Celtis occidentalis': [0.00023],
#  'Celtis julianae': [3e-05],
#  'Staphylea bumalda': [3e-05],
#  'Acer japonicum': [0.0001],
#  'Sophora': [0.00013],
#  'Gleditsia': [7e-05],
#  'Pinus mugo mughus': [7e-05],
#  'Magnolia hybride': [0.0001],
#  'Liquidambar orientalis': [7e-05],
#  'Sequoia sempervirens': [3e-05],
#  'Chitalpa tashkentensis': [0.00013],
#  'Betula': [0.0001],
#  'Prunus campanulata': [7e-05],
#  'Ligustrum japonicum': [7e-05],
#  'Acer davidii': [0.0002],
#  'Prunus serotina': [7e-05],
#  'Larix decidua': [0.00016],
#  'Picea orientalis': [0.00059],
#  'Halesia monticola': [3e-05],
#  'Quercus acutissima': [0.0002],
#  'Malus coronaria': [3e-05],
#  'Ligustrum sinense': [0.0001],
#  'Malus pumila': [7e-05],
#  'Quercus hispanica': [3e-05],
#  'Acer hippocastanum': [3e-05],
#  'Aesculus chandelle seche': [7e-05],
#  'Nyssa sylvatica': [3e-05],
#  'Acer utilis': [3e-05],
#  'Chamaecyparis nooktensis': [3e-05],
#  'Punica granatum': [0.0001],
#  'Sorbus cuspidata': [0.00013],
#  'Lonicera fragmantissima': [0.0001],
#  'Ulmus pumila': [3e-05],
#  'Sorbus chamaemespilus': [3e-05],
#  'Sciadopitys verticillata': [3e-05],
#  'Quercus variabilis': [0.0001],
#  'Juniperus virginiana': [3e-05],
#  'Cercidiphyllum magnificum': [3e-05],
#  'Quercus fraxinifolia': [3e-05],
#  'Diospyros virginiana': [0.0002],
#  'Magnolia heptapeta': [3e-05],
#  'Juniperus drupacea': [3e-05],
#  'Sorbopyrus auricularis': [3e-05],
#  'Poncinos': [3e-05],
#  'Prunus yedoensis': [0.00039],
#  'Acer carpinifolia': [7e-05],
#  'Liquidambar tulipifera': [3e-05],
#  'Cedrus sinensis': [3e-05],
#  'Crataegus crus-galli': [7e-05]}

# %% [markdown]
# ### ● (plus dur) Comment la pratique de plantation a-t-elle évolué au cours du temps? Diversifie-t-on plus maintenant qu’avant ?

# %%
genre_bota_annee = []

with open('../data/trees.csv', newline="") as file:

    reader = csv.DictReader(file, delimiter=",")
    
    for row in reader:
        genre_bota_annee.append([row["ANNEEDEPLANTATION"], row["GENRE_BOTA"]])

genre_bota_annee
# Out:
# [['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2000', 'Ginkgo'],
#  ['2017', 'Salix'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1983', 'Catalpa'],
#  ['1983', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['2017', 'Pyrus'],
#  ['2017', 'Robinia'],
#  ['2017', 'Robinia'],
#  ['2017', ''],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Zelkova'],
#  ['2008', 'Parrotia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fagus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Fagus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Picea'],
#  ['1966', 'Taxus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Cupressus'],
#  ['1966', 'Sequoiadendron'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fagus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Pinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Betula'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Tilia'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['1970', 'Acer'],
#  ['1970', 'Cedrus'],
#  ['2009', 'Liriodendron'],
#  ['1970', 'Acer'],
#  ['1970', 'Pinus'],
#  ['1970', 'Populus'],
#  ['2009', 'Celtis'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2006', 'Tilia'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Populus'],
#  ['2006', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Thuja'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Picea'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['1970', 'Robinia'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Fagus'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['2011', 'Acer'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Robinia'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['2009', 'Celtis'],
#  ['2009', 'Acer'],
#  ['1970', 'Pinus'],
#  ['1970', 'Pinus'],
#  ['2006', 'Tilia'],
#  ['1970', 'Thuja'],
#  ['2009', 'Prunus'],
#  ['1970', 'Picea'],
#  ['2006', 'Tilia'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Fraxinus'],
#  ['1970', 'Thuja'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['1970', 'Robinia'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['2009', 'Prunus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Robinia'],
#  ['1970', 'Platanus'],
#  ['1970', 'Pinus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Populus'],
#  ['1970', 'Populus'],
#  ['1970', 'Cedrus'],
#  ['2007', 'Pinus'],
#  ['1970', 'Calocedrus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['2006', 'Tilia'],
#  ['1970', 'Prunus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Platanus'],
#  ['1970', 'Platanus'],
#  ['1970', 'Platanus'],
#  ['2009', 'Celtis'],
#  ['2008', 'Cedrus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Paulownia'],
#  ['1970', 'Fraxinus'],
#  ['1970', 'Calocedrus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Populus'],
#  ['1970', 'Fraxinus'],
#  ['2009', 'Zelkova'],
#  ['2009', 'Celtis'],
#  ['1970', 'Pinus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Robinia'],
#  ['1970', 'Pinus'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Tilia'],
#  ['2011', 'Celtis'],
#  ['2011', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Thuja'],
#  ['2011', 'Celtis'],
#  ['2011', 'Celtis'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Picea'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Sophora'],
#  ['1970', 'Robinia'],
#  ['1970', 'Sophora'],
#  ['1970', 'Gymnocladus'],
#  ['2009', 'Ulmus'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['2009', 'Celtis'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['2009', 'Prunus'],
#  ['1970', 'Picea'],
#  ['1970', 'Sophora'],
#  ['1970', 'Corylus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['2009', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Pinus'],
#  ['1970', 'Pinus'],
#  ['2009', 'Sorbus'],
#  ['1970', 'Platanus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Fraxinus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Pinus'],
#  ['1970', 'Thuja'],
#  ['1970', 'Cedrus'],
#  ['2006', 'Tilia'],
#  ['2006', 'Tilia'],
#  ['2007', 'Prunus'],
#  ['2009', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Robinia'],
#  ['1970', 'Liquidambar'],
#  ['2006', 'Tilia'],
#  ['1970', 'Sophora'],
#  ['1970', 'Platanus'],
#  ['1970', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Morus'],
#  ['1970', 'Pinus'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Platanus'],
#  ['1970', 'Sorbus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Corylus'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Pinus'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Acer'],
#  ['1981', 'Tilia'],
#  ['', ''],
#  ['', ''],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['2009', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Acer'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['2009', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Acer'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['1986', 'Clerodendron'],
#  ['1966', 'Taxus'],
#  ['1966', 'Gleditsia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Libocedrus'],
#  ['1966', 'Quercus'],
#  ['1966', 'Fraxinus'],
#  ['2007', 'Lagerstroemia'],
#  ['2000', 'Celtis'],
#  ['1966', 'Acer'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Acer'],
#  ['1966', 'Taxodium'],
#  ['1966', 'Alnus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Acer'],
#  ['2014', 'Acer'],
#  ['2014', 'Acer'],
#  ['2014', 'Quercus'],
#  ['1966', 'Cupressus'],
#  ['2006', 'Cercidiphyllum'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Taxus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Robinia'],
#  ['1966', 'Acer'],
#  ['1966', 'Cedrus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Liriodendron'],
#  ['1966', 'Taxus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Cedrus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Ilex'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Pinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Tilia'],
#  ['1966', 'Acer'],
#  ['1966', 'Robinia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Tilia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Magnolia'],
#  ['2006', 'Malus'],
#  ['2006', 'Malus'],
#  ['2006', 'Malus'],
#  ['2006', 'Fraxinus'],
#  ['2011', 'Cedrela'],
#  ['2011', 'Cedrela'],
#  ['2006', 'Prunus'],
#  ['1975', 'Photinia'],
#  ['2006', 'Malus'],
#  ['2011', 'Paulownia'],
#  ['2011', 'Cedrela'],
#  ['2006', 'Sorbus'],
#  ['2006', 'Prunus'],
#  ['2006', 'Prunus'],
#  ['2006', 'Prunus'],
#  ['2011', 'Paulownia'],
#  ['2006', 'Sorbus'],
#  ['2012', 'Paulownia'],
#  ['2006', 'Prunus'],
#  ['2006', 'Malus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1983', 'Platanus'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1980', 'Betula'],
#  ['1980', 'Robinia'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1979', 'Tilia'],
#  ['1979', 'Tilia'],
#  ['1979', 'Tilia'],
#  ['1979', 'Pinus'],
#  ['1979', 'Robinia'],
#  ['1979', 'Paulownia'],
#  ['1979', 'Pinus'],
#  ['1979', 'Robinia'],
#  ['1979', 'Pinus'],
#  ['2007', 'Tetradium'],
#  ['2007', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2009', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['2011', 'Tetradium'],
#  ['2007', 'Tetradium'],
#  ['2009', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['2011', 'Tilia'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2012', 'Liriodendron'],
#  ['2012', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2009', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2011', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2011', 'Fraxinus'],
#  ['2011', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2009', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Acer'],
#  ['1996', 'Acer'],
#  ['1996', 'Populus'],
#  ['1996', 'Acer'],
#  ['1996', 'Populus'],
#  ['1996', 'Acer'],
#  ['1996', 'Acer'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Ulmus'],
#  ['1981', 'Liriodendron'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['2014', 'Platanus'],
#  ['2014', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['2009', 'Acer'],
#  ['1990', 'Acer'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Cupressus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Acer'],
#  ['1978', 'Pinus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Thuja'],
#  ['1978', 'Acer'],
#  ['2009', 'Koelreuteria'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Pinus'],
#  ['1980', 'Acer'],
#  ['1980', 'Betula'],
#  ['1980', 'Malus'],
#  ['2014', 'Halesia'],
#  ['1980', 'Crataegus'],
#  ['1980', 'Acer'],
#  ['1980', 'Acer'],
#  ['1980', 'Acer'],
#  ['1980', 'Cedrus'],
#  ['1980', 'Crataegus'],
#  ['1970', 'Morus'],
#  ['1970', 'Morus'],
#  ['1970', 'Morus'],
#  ['1970', 'Aesculus'],
#  ['1970', 'Aesculus'],
#  ['2011', 'Prunus'],
#  ['2010', 'Prunus'],
#  ['2010', 'Prunus'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['2013', 'Ptelea'],
#  ['2013', 'Ptelea'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Betula'],
#  ['1975', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1989', 'Quercus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Acer'],
#  ['1999', 'Celtis'],
#  ['2007', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Acer'],
#  ['', ''],
#  ['', ''],
#  ['1999', 'Chimonanthus'],
#  ['1999', 'Thuja'],
#  ['1999', 'Chimonanthus'],
#  ['1999', 'Chimonanthus'],
#  ['1998', 'Pyrus'],
#  ['1998', 'Pyrus'],
#  ['1998', 'Pyrus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Pinus'],
#  ['1980', 'Betula'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Picea'],
#  ['1980', 'Populus'],
#  ['1980', 'Robinia'],
#  ['1980', 'Acer'],
#  ['1980', 'Populus'],
#  ['1980', 'Tilia'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Betula'],
#  ['1980', 'Populus'],
#  ['1980', 'Betula'],
#  ['1980', 'Ulmus'],
#  ['1980', 'Salix'],
#  ['1980', 'Populus'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['2015', 'Tilia'],
#  ['2015', 'Alnus'],
#  ['2015', 'Acer'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Ulmus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Alnus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Ulmus'],
#  ['2015', 'Acer'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Amélanchier'],
#  ['2015', 'Alnus'],
#  ['1975', 'Acer'],
#  ['1975', 'Carpinus'],
#  ['1975', 'Carpinus'],
#  ['1975', 'Betula'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Acer'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Acer'],
#  ...]

# %%
bota_genre_annee = []

with open('../data/trees.csv', newline="") as file:

    reader = csv.DictReader(file, delimiter=",")
    next(reader)

    for row in reader:
        bota_genre_annee.append([row["ANNEEDEPLANTATION"], row["GENRE_BOTA"]])

bota_genre_annee
# Out:
# [['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', 'Platanus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2017', ''],
#  ['2000', 'Ginkgo'],
#  ['2017', 'Salix'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1983', 'Catalpa'],
#  ['1983', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['1976', 'Platanus'],
#  ['2017', 'Pyrus'],
#  ['2017', 'Robinia'],
#  ['2017', 'Robinia'],
#  ['2017', ''],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Zelkova'],
#  ['2008', 'Parrotia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fagus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Fagus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Picea'],
#  ['1966', 'Taxus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Cupressus'],
#  ['1966', 'Sequoiadendron'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fagus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Pinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Betula'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Tilia'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['1970', 'Acer'],
#  ['1970', 'Cedrus'],
#  ['2009', 'Liriodendron'],
#  ['1970', 'Acer'],
#  ['1970', 'Pinus'],
#  ['1970', 'Populus'],
#  ['2009', 'Celtis'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2006', 'Tilia'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Populus'],
#  ['2006', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Thuja'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Picea'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['1970', 'Robinia'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Fagus'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['2011', 'Acer'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Robinia'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['2009', 'Celtis'],
#  ['2009', 'Acer'],
#  ['1970', 'Pinus'],
#  ['1970', 'Pinus'],
#  ['2006', 'Tilia'],
#  ['1970', 'Thuja'],
#  ['2009', 'Prunus'],
#  ['1970', 'Picea'],
#  ['2006', 'Tilia'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Fraxinus'],
#  ['1970', 'Thuja'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['1970', 'Robinia'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['2009', 'Prunus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Populus'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Robinia'],
#  ['1970', 'Platanus'],
#  ['1970', 'Pinus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Populus'],
#  ['1970', 'Populus'],
#  ['1970', 'Cedrus'],
#  ['2007', 'Pinus'],
#  ['1970', 'Calocedrus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['2006', 'Tilia'],
#  ['1970', 'Prunus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Platanus'],
#  ['1970', 'Platanus'],
#  ['1970', 'Platanus'],
#  ['2009', 'Celtis'],
#  ['2008', 'Cedrus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Paulownia'],
#  ['1970', 'Fraxinus'],
#  ['1970', 'Calocedrus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Populus'],
#  ['1970', 'Fraxinus'],
#  ['2009', 'Zelkova'],
#  ['2009', 'Celtis'],
#  ['1970', 'Pinus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Picea'],
#  ['2009', 'Celtis'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Robinia'],
#  ['1970', 'Pinus'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Tilia'],
#  ['2011', 'Celtis'],
#  ['2011', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Thuja'],
#  ['2011', 'Celtis'],
#  ['2011', 'Celtis'],
#  ['2011', 'Sorbus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Picea'],
#  ['1970', 'Liquidambar'],
#  ['1970', 'Sophora'],
#  ['1970', 'Robinia'],
#  ['1970', 'Sophora'],
#  ['1970', 'Gymnocladus'],
#  ['2009', 'Ulmus'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['2009', 'Celtis'],
#  ['1970', 'Sophora'],
#  ['1970', 'Pinus'],
#  ['2009', 'Prunus'],
#  ['1970', 'Picea'],
#  ['1970', 'Sophora'],
#  ['1970', 'Corylus'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Acer'],
#  ['2006', 'Tilia'],
#  ['2009', 'Celtis'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['2009', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Pinus'],
#  ['1970', 'Pinus'],
#  ['2009', 'Sorbus'],
#  ['1970', 'Platanus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Fraxinus'],
#  ['2009', 'Zelkova'],
#  ['1970', 'Pinus'],
#  ['1970', 'Thuja'],
#  ['1970', 'Cedrus'],
#  ['2006', 'Tilia'],
#  ['2006', 'Tilia'],
#  ['2007', 'Prunus'],
#  ['2009', 'Acer'],
#  ['1970', 'Acer'],
#  ['1970', 'Robinia'],
#  ['1970', 'Liquidambar'],
#  ['2006', 'Tilia'],
#  ['1970', 'Sophora'],
#  ['1970', 'Platanus'],
#  ['1970', 'Acer'],
#  ['1970', 'Picea'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Morus'],
#  ['1970', 'Pinus'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Platanus'],
#  ['1970', 'Sorbus'],
#  ['1970', 'Sophora'],
#  ['1970', 'Ginkgo'],
#  ['1970', 'Populus'],
#  ['1970', 'Acer'],
#  ['2009', 'Celtis'],
#  ['1970', 'Cedrus'],
#  ['1970', 'Corylus'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Liriodendron'],
#  ['2002', 'Betula'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Pinus'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Tilia'],
#  ['1981', 'Acer'],
#  ['1981', 'Tilia'],
#  ['', ''],
#  ['', ''],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['2009', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Acer'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['2009', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Tilia'],
#  ['1974', 'Acer'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['2002', 'Liquidambar'],
#  ['1986', 'Clerodendron'],
#  ['1966', 'Taxus'],
#  ['1966', 'Gleditsia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Libocedrus'],
#  ['1966', 'Quercus'],
#  ['1966', 'Fraxinus'],
#  ['2007', 'Lagerstroemia'],
#  ['2000', 'Celtis'],
#  ['1966', 'Acer'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Acer'],
#  ['1966', 'Taxodium'],
#  ['1966', 'Alnus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Amélanchier'],
#  ['2014', 'Acer'],
#  ['2014', 'Acer'],
#  ['2014', 'Acer'],
#  ['2014', 'Quercus'],
#  ['1966', 'Cupressus'],
#  ['2006', 'Cercidiphyllum'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Acer'],
#  ['1966', 'Taxus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Robinia'],
#  ['1966', 'Acer'],
#  ['1966', 'Cedrus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Liriodendron'],
#  ['1966', 'Taxus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Cedrus'],
#  ['1995', 'Pyrus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Ilex'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Pinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Magnolia'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Tilia'],
#  ['1966', 'Acer'],
#  ['1966', 'Robinia'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Picea'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Tilia'],
#  ['1966', 'Fraxinus'],
#  ['1966', 'Taxus'],
#  ['1966', 'Alnus'],
#  ['1966', 'Magnolia'],
#  ['2006', 'Malus'],
#  ['2006', 'Malus'],
#  ['2006', 'Malus'],
#  ['2006', 'Fraxinus'],
#  ['2011', 'Cedrela'],
#  ['2011', 'Cedrela'],
#  ['2006', 'Prunus'],
#  ['1975', 'Photinia'],
#  ['2006', 'Malus'],
#  ['2011', 'Paulownia'],
#  ['2011', 'Cedrela'],
#  ['2006', 'Sorbus'],
#  ['2006', 'Prunus'],
#  ['2006', 'Prunus'],
#  ['2006', 'Prunus'],
#  ['2011', 'Paulownia'],
#  ['2006', 'Sorbus'],
#  ['2012', 'Paulownia'],
#  ['2006', 'Prunus'],
#  ['2006', 'Malus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['1983', 'Platanus'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1983', 'Platanus'],
#  ['2009', 'Liriodendron'],
#  ['2009', 'Liriodendron'],
#  ['1980', 'Betula'],
#  ['1980', 'Robinia'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['2004', 'Celtis'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1979', 'Tilia'],
#  ['1979', 'Tilia'],
#  ['1979', 'Tilia'],
#  ['1979', 'Pinus'],
#  ['1979', 'Robinia'],
#  ['1979', 'Paulownia'],
#  ['1979', 'Pinus'],
#  ['1979', 'Robinia'],
#  ['1979', 'Pinus'],
#  ['2007', 'Tetradium'],
#  ['2007', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2010', 'Tetradium'],
#  ['2009', 'Tetradium'],
#  ['2013', 'Tetradium'],
#  ['2011', 'Tetradium'],
#  ['2007', 'Tetradium'],
#  ['2009', 'Tetradium'],
#  ['1999', 'Tetradium'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['1991', 'Tilia'],
#  ['2011', 'Tilia'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2012', 'Liriodendron'],
#  ['2012', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2011', 'Liriodendron'],
#  ['2009', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2011', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2011', 'Fraxinus'],
#  ['2011', 'Fraxinus'],
#  ['2010', 'Fraxinus'],
#  ['2009', 'Pinus'],
#  ['2010', 'Fraxinus'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Acer'],
#  ['1996', 'Acer'],
#  ['1996', 'Populus'],
#  ['1996', 'Acer'],
#  ['1996', 'Populus'],
#  ['1996', 'Acer'],
#  ['1996', 'Acer'],
#  ['1996', 'Ulmus'],
#  ['1996', 'Ulmus'],
#  ['1981', 'Liriodendron'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['2014', 'Platanus'],
#  ['2014', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['1999', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2008', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['2001', 'Platanus'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['1990', 'Acer'],
#  ['2009', 'Acer'],
#  ['1990', 'Acer'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Cupressus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Acer'],
#  ['1978', 'Pinus'],
#  ['1978', 'Pinus'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Thuja'],
#  ['1978', 'Acer'],
#  ['2009', 'Koelreuteria'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Acer'],
#  ['1978', 'Pinus'],
#  ['1980', 'Acer'],
#  ['1980', 'Betula'],
#  ['1980', 'Malus'],
#  ['2014', 'Halesia'],
#  ['1980', 'Crataegus'],
#  ['1980', 'Acer'],
#  ['1980', 'Acer'],
#  ['1980', 'Acer'],
#  ['1980', 'Cedrus'],
#  ['1980', 'Crataegus'],
#  ['1970', 'Morus'],
#  ['1970', 'Morus'],
#  ['1970', 'Morus'],
#  ['1970', 'Aesculus'],
#  ['1970', 'Aesculus'],
#  ['2011', 'Prunus'],
#  ['2010', 'Prunus'],
#  ['2010', 'Prunus'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2002', 'Acer'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['2001', 'Liriodendron'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1984', 'Liquidambar'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['2013', 'Ptelea'],
#  ['2013', 'Ptelea'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['1961', 'Populus'],
#  ['2017', ''],
#  ['2017', ''],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Platanus'],
#  ['1975', 'Betula'],
#  ['1975', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1965', 'Platanus'],
#  ['1965', 'Prunus'],
#  ['1989', 'Quercus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Acer'],
#  ['1999', 'Celtis'],
#  ['2007', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Fraxinus'],
#  ['1989', 'Acer'],
#  ['', ''],
#  ['', ''],
#  ['1999', 'Chimonanthus'],
#  ['1999', 'Thuja'],
#  ['1999', 'Chimonanthus'],
#  ['1999', 'Chimonanthus'],
#  ['1998', 'Pyrus'],
#  ['1998', 'Pyrus'],
#  ['1998', 'Pyrus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Pinus'],
#  ['1980', 'Betula'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Picea'],
#  ['1980', 'Populus'],
#  ['1980', 'Robinia'],
#  ['1980', 'Acer'],
#  ['1980', 'Populus'],
#  ['1980', 'Tilia'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Populus'],
#  ['1980', 'Betula'],
#  ['1980', 'Populus'],
#  ['1980', 'Betula'],
#  ['1980', 'Ulmus'],
#  ['1980', 'Salix'],
#  ['1980', 'Populus'],
#  ['1980', 'Pinus'],
#  ['1980', 'Populus'],
#  ['2015', 'Tilia'],
#  ['2015', 'Alnus'],
#  ['2015', 'Acer'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Ulmus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Acer'],
#  ['2015', 'Acer'],
#  ['2015', 'Alnus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Ulmus'],
#  ['2015', 'Acer'],
#  ['2015', 'Fraxinus'],
#  ['2015', 'Alnus'],
#  ['2015', 'Amélanchier'],
#  ['2015', 'Alnus'],
#  ['1975', 'Acer'],
#  ['1975', 'Carpinus'],
#  ['1975', 'Carpinus'],
#  ['1975', 'Betula'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Acer'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Koelreuteria'],
#  ['1975', 'Acer'],
#  ['1975', 'Koelreuteria'],
#  ...]
